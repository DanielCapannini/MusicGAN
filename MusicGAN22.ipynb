# %% [markdown]
# # MIDI music generation with GAN

# %%
# !wget https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0-midi.zip
# !unzip 'maestro-v3.0.0-midi.zip'
# !rm 'maestro-v3.0.0-midi.zip'
dataset_path = "maestro-v3.0.0"
# Out:
# --2025-08-18 13:54:15--  https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0-midi.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.96.207, 108.177.119.207, 108.177.127.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.96.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58416533 (56M) [application/octet-stream]
# Saving to: ‘maestro-v3.0.0-midi.zip’
#
# maestro-v3.0.0-midi 100%[===================>]  55.71M  28.5MB/s    in 2.0s
#
# 2025-08-18 13:54:17 (28.5 MB/s) - ‘maestro-v3.0.0-midi.zip’ saved [58416533/58416533]
#
# Archive:  maestro-v3.0.0-midi.zip
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_08_R1_2004_01-02_ORIG_MID--AUDIO_08_R1_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R1_2004_01-03_ORIG_MID--AUDIO_14_R1_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_01_R1_2004_01-02_ORIG_MID--AUDIO_01_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R1_2004_06_ORIG_MID--AUDIO_04_R1_2004_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_10_R1_2004_01-02_ORIG_MID--AUDIO_10_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_05_R1_2004_02-03_ORIG_MID--AUDIO_05_R1_2004_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_11_R1_2004_01-02_ORIG_MID--AUDIO_11_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_03_Track03_wav--1.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--2.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R1_2004_01-02_ORIG_MID--AUDIO_04_R1_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_12_Track12_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_08_R1_2004_01-02_ORIG_MID--AUDIO_08_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_13_Track13_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R1_2004_01-02_ORIG_MID--AUDIO_04_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_17_Track17_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R1_2004_04_ORIG_MID--AUDIO_15_R1_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_05_Track05_wav--2.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_01_R1_2004_01-02_ORIG_MID--AUDIO_01_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_11_R1_2004_01-02_ORIG_MID--AUDIO_11_R1_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_10_R1_2004_01-02_ORIG_MID--AUDIO_10_R1_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_18_R1_2004_04_ORIG_MID--AUDIO_18_R1_2004_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R1_2004_03_ORIG_MID--AUDIO_15_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_12_Track12_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_08_R1_2004_03_ORIG_MID--AUDIO_08_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_04_ORIG_MID--AUDIO_17_R1_2004_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_05_Track05_wav--1.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_06_R1_2004_01_ORIG_MID--AUDIO_06_R1_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_21_R1_2004_03_ORIG_MID--AUDIO_21_R1_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_21_R1_2004_02_ORIG_MID--AUDIO_21_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_10_R1_2004_05_ORIG_MID--AUDIO_10_R1_2004_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_10_R1_2004_03-04_ORIG_MID--AUDIO_10_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MID--AUDIO_21_R1_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_11_R1_2004_03-04_ORIG_MID--AUDIO_11_R1_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_01_R1_2004_04-05_ORIG_MID--AUDIO_01_R1_2004_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R1_2004_01-02_ORIG_MID--AUDIO_15_R1_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R1_2004_01-02_ORIG_MID--AUDIO_15_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_01_R1_2004_04-05_ORIG_MID--AUDIO_01_R1_2004_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_21_R1_2004_02_ORIG_MID--AUDIO_21_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_06_R1_2004_02-03_ORIG_MID--AUDIO_06_R1_2004_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R1_2004_01-03_ORIG_MID--AUDIO_14_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG_MID--AUDIO_03_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG_MID--AUDIO_03_R1_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--2.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_04_ORIG_MID--AUDIO_17_R1_2004_11_Track11_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--1.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_11_R1_2004_03-04_ORIG_MID--AUDIO_11_R1_2004_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_22_R2_2011_MID--AUDIO_R2-D5_11_Track11_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_02_R1_2011_MID--AUDIO_R1-D1_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_21_R1_2011_MID--AUDIO_R1-D8_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_25_R2_2011_MID--AUDIO_R2-D6_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_16_Track16_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_17_Track17_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R2-D1_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R2_2011_MID--AUDIO_R2-D4_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_04_R2_2011_MID--AUDIO_R2-D2_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_12_Track12_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_12_Track12_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1-D5_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_11_Track11_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_21_R1_2011_MID--AUDIO_R1-D8_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_09_R2_2011_MID--AUDIO_R2-D3_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_06_R3_2011_MID--AUDIO_R3-D3_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_14_Track14_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_15_Track15_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1-D3_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_15_Track15_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1-D6_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_14_Track14_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R2-D1_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_10_R2_2011_MID--AUDIO_R2-D3_11_Track11_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_15_Track15_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1-D5_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_23_R2_2011_MID--AUDIO_R2-D6_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_06_R2_2011_MID--AUDIO_R2-D2_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_09_R2_2011_MID--AUDIO_R2-D3_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R2_2011_MID--AUDIO_R2-D5_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R2_2011_MID--AUDIO_R2-D5_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_02_R1_2011_MID--AUDIO_R1-D1_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R2-D1_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_10_R1_2011_MID--AUDIO_R1-D4_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_16_R3_2011_MID--AUDIO_R3-D5_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_02_R2_2011_MID--AUDIO_R2-D1_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1-D3_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_21_R1_2011_MID--AUDIO_R1-D8_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_15_Track15_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_15_Track15_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_20_R1_2011_MID--AUDIO_R1-D8_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_02_R2_2011_MID--AUDIO_R2-D1_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_12_Track12_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1-D3_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_12_Track12_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_11_Track11_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_22_R2_2011_MID--AUDIO_R2-D5_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_13_Track13_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_10_R1_2011_MID--AUDIO_R1-D4_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_23_R3_2011_MID--AUDIO_R3-D8_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_22_R2_2011_MID--AUDIO_R2-D5_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_25_R1_2011_MID--AUDIO_R1-D9_14_Track14_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_16_Track16_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_11_Track11_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R2_2011_MID--AUDIO_R2-D4_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_23_R2_2011_MID--AUDIO_R2-D6_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_13_Track13_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_06_R3_2011_MID--AUDIO_R3-D3_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_13_Track13_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_18_Track18_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_20_R1_2011_MID--AUDIO_R1-D8_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R2_2011_MID--AUDIO_R2-D5_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_14_Track14_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_25_R2_2011_MID--AUDIO_R2-D6_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_14_Track14_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_04_R2_2011_MID--AUDIO_R2-D2_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_15_Track15_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_06_R3_2011_MID--AUDIO_R3-D3_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_13_Track13_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_06_R2_2011_MID--AUDIO_R2-D2_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_21_R1_2011_MID--AUDIO_R1-D8_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_13_Track13_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1-D3_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1-D5_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_16_R2_2011_MID--AUDIO_R2-D4_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_23_R3_2011_MID--AUDIO_R3-D8_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_16_R2_2011_MID--AUDIO_R2-D4_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1-D6_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_20_R1_2011_MID--AUDIO_R1-D8_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_23_R3_2011_MID--AUDIO_R3-D8_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_25_R1_2011_MID--AUDIO_R1-D9_15_Track15_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_10_R2_2011_MID--AUDIO_R2-D3_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_09_Track09_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R2_2011_MID--AUDIO_R2-D4_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1-D6_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_14_Track14_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_11_Track11_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_12_Track12_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_12_R2_2011_MID--AUDIO_R2-D4_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_02_R1_2011_MID--AUDIO_R1-D1_10_Track10_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_10_R1_2011_MID--AUDIO_R1-D4_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2011/MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_17_Track17_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_07_R1_2006_01-04_ORIG_MID--AUDIO_07_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_16_R1_2006_01-04_ORIG_MID--AUDIO_16_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_16_R1_2006_01-04_ORIG_MID--AUDIO_16_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_10_R1_2006_01-04_ORIG_MID--AUDIO_10_R1_2006_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_20_R1_2006_01-04_ORIG_MID--AUDIO_20_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_11_R1_2006_01-06_ORIG_MID--AUDIO_11_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_06_R1_2006_01-04_ORIG_MID--AUDIO_06_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_14_R1_2006_01-05_ORIG_MID--AUDIO_14_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_23_R2_2006_01_ORIG_MID--AUDIO_23_R2_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_23_R1_2006_01-05_ORIG_MID--AUDIO_23_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_08_R1_2006_01-04_ORIG_MID--AUDIO_08_R1_2006_Disk1_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_09_R1_2006_01-04_ORIG_MID--AUDIO_09_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_08_R2_2006_01_ORIG_MID--AUDIO_08_R2_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_20_R1_2006_01-04_ORIG_MID--AUDIO_20_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_15_R1_2006_01-05_ORIG_MID--AUDIO_15_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_23_R1_2006_01-05_ORIG_MID--AUDIO_23_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_23_R2_2006_01_ORIG_MID--AUDIO_23_R2_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_06_R1_2006_01-04_ORIG_MID--AUDIO_06_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_16_R1_2006_01-04_ORIG_MID--AUDIO_16_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_09_R1_2006_01-04_ORIG_MID--AUDIO_09_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_15_R1_2006_01-05_ORIG_MID--AUDIO_15_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_10_R1_2006_01-04_ORIG_MID--AUDIO_10_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_07_Track07_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_08_R2_2006_01_ORIG_MID--AUDIO_08_R2_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_08_R2_2006_01_ORIG_MID--AUDIO_08_R2_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_23_R2_2006_01_ORIG_MID--AUDIO_23_R2_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_14_R1_2006_01-05_ORIG_MID--AUDIO_14_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_06_R1_2006_01-04_ORIG_MID--AUDIO_06_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_23_R2_2006_01_ORIG_MID--AUDIO_23_R2_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_09_R1_2006_01-04_ORIG_MID--AUDIO_09_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_07_R1_2006_01-04_ORIG_MID--AUDIO_07_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_06_R1_2006_01-04_ORIG_MID--AUDIO_06_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_10_R1_2006_01-04_ORIG_MID--AUDIO_10_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_11_R1_2006_01-06_ORIG_MID--AUDIO_11_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_08_R1_2006_01-04_ORIG_MID--AUDIO_08_R1_2006_Disk1_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_14_R1_2006_01-05_ORIG_MID--AUDIO_14_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_05_Track05_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_08_Track08_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_07_R1_2006_01-04_ORIG_MID--AUDIO_07_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_08_R1_2006_01-04_ORIG_MID--AUDIO_08_R1_2006_Disk1_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_09_R1_2006_01-04_ORIG_MID--AUDIO_09_R1_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_06_Track06_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_04_Track04_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_07_R1_2006_01-04_ORIG_MID--AUDIO_07_R1_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_11_R1_2006_01-06_ORIG_MID--AUDIO_11_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_02_Track02_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_15_R1_2006_01-05_ORIG_MID--AUDIO_15_R1_2006_01_Track01_wav.midi
#   inflating: maestro-v3.0.0/2006/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_03_R1_2015_wav--1.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--2.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_19_R2_2015_wav--2.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_11_R1_2015_wav--2.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_20_R1_2015_wav--4.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_07_R1_2015_wav--1.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_05_R1_2015_wav--4.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_04_R1_2015_wav--1.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_16_R1_2015_wav--1.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_09_R1_2015_wav--2.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_21_R2_2015_wav--1.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--1.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_08_R2_2015_wav--3.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--3.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_15_R1_2015_wav--3.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_06_R1_2015_wav--6.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_06_R1_2015_wav--1.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_18_R1_2015_wav--3.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_15_R1_2015_wav--2.midi
#   inflating: maestro-v3.0.0/2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_16_R1_2015_wav--3.midi
# ...
#   inflating: maestro-v3.0.0/2014/MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_11_R1_2014_wav--1.midi
#   inflating: maestro-v3.0.0/2014/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--5.midi
#   inflating: maestro-v3.0.0/2014/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_03_R1_2014_wav--5.midi
#   inflating: maestro-v3.0.0/2014/MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_21_R1_2014_wav--2.midi
#   inflating: maestro-v3.0.0/2014/MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_06_R1_2014_wav--3.midi
#   inflating: maestro-v3.0.0/2014/MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_07_R1_2014_wav--5.midi
#   inflating: maestro-v3.0.0/2014/MIDI-UNPROCESSED_19-20_R1_2014_MID--AUDIO_19_R1_2014_wav--2.midi
#   inflating: maestro-v3.0.0/2014/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--4.midi
#   inflating: maestro-v3.0.0/2014/MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_22_R1_2014_wav--4.midi
#   inflating: maestro-v3.0.0/2014/MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_11_R1_2014_wav--3.midi
#   inflating: maestro-v3.0.0/maestro-v3.0.0.json
#   inflating: maestro-v3.0.0/LICENSE
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_06_R1_2009_03-07_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_04_R1_2009_01-03_ORIG_MID--AUDIO_04_R1_2009_04_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_16_R1_2009_01-02_ORIG_MID--AUDIO_16_R1_2009_16_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_10_R2_2009_01_ORIG_MID--AUDIO_10_R2_2009_10_R2_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_01_R1_2009_01-04_ORIG_MID--AUDIO_01_R1_2009_01_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_06_R1_2009_03-07_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_20_R1_2009_06-07_ORIG_MID--AUDIO_20_R1_2009_20_R1_2009_06_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_17_R1_2009_01-03_ORIG_MID--AUDIO_17_R1_2009_17_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_21_R1_2009_01-03_ORIG_MID--AUDIO_21_R1_2009_21_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_06_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_05_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_16_R2_2009_01_ORIG_MID--AUDIO_16_R2_2009_16_R2_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_06_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_16_R1_2009_03-06_ORIG_MID--AUDIO_16_R1_2009_16_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_06_R1_2009_03-07_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_05_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_17_R1_2009_01-03_ORIG_MID--AUDIO_17_R1_2009_17_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_10_R1_2009_03-05_ORIG_MID--AUDIO_10_R1_2009_10_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_19_R1_2009_01-02_ORIG_MID--AUDIO_19_R1_2009_19_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_02_R1_2009_01-02_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_21_R2_2009_01_ORIG_MID--AUDIO_21_R2_2009_21_R2_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_16_R1_2009_01-02_ORIG_MID--AUDIO_16_R1_2009_16_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_04_R1_2009_04-06_ORIG_MID--AUDIO_04_R1_2009_04_R1_2009_06_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_21_R1_2009_01-03_ORIG_MID--AUDIO_21_R1_2009_21_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_18_R1_2009_04_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_10_R1_2009_01-02_ORIG_MID--AUDIO_10_R1_2009_10_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_12_R1_2009_03-05_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_05_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_13_R1_2009_01-03_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_17_R1_2009_04_ORIG_MID--AUDIO_17_R1_2009_17_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_10_R2_2009_01_ORIG_MID--AUDIO_10_R2_2009_10_R2_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_05_R1_2009_03-05_ORIG_MID--AUDIO_05_R1_2009_05_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_17_R1_2009_01-03_ORIG_MID--AUDIO_17_R1_2009_17_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_16_R2_2009_01_ORIG_MID--AUDIO_16_R2_2009_16_R2_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_10_R1_2009_03-05_ORIG_MID--AUDIO_10_R1_2009_10_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_07_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_08_R1_2009_05-06_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_06_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_15_R1_2009_03-06_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_15_R1_2009_03-06_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_06_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_15_R1_2009_01-02_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_04_R1_2009_04-06_ORIG_MID--AUDIO_04_R1_2009_04_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_08_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_15_R1_2009_03-06_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_05_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_15_R1_2009_01-02_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_08_R2_2009_01_ORIG_MID--AUDIO_08_R2_2009_08_R2_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_06_R1_2009_03-07_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_07_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_08_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_13_R1_2009_01-03_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_21_R2_2009_01_ORIG_MID--AUDIO_21_R2_2009_21_R2_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_08_R2_2009_01_ORIG_MID--AUDIO_08_R2_2009_08_R2_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_04_R1_2009_04-06_ORIG_MID--AUDIO_04_R1_2009_04_R1_2009_05_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_06_R1_2009_01-02_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_20_R1_2009_01-05_ORIG_MID--AUDIO_20_R1_2009_20_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_05_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_09_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_08_R2_2009_01_ORIG_MID--AUDIO_08_R2_2009_08_R2_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_05_R1_2009_01-02_ORIG_MID--AUDIO_05_R1_2009_05_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_01_R1_2009_01-04_ORIG_MID--AUDIO_01_R1_2009_01_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_12_R1_2009_01-02_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_02_R1_2009_01-02_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_12_R1_2009_03-05_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_07_R1_2009_01-03_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_06_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_05_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_01_R1_2009_01-04_ORIG_MID--AUDIO_01_R1_2009_01_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_08_R2_2009_01_ORIG_MID--AUDIO_08_R2_2009_08_R2_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_10_R1_2009_01-02_ORIG_MID--AUDIO_10_R1_2009_10_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_20_R1_2009_01-05_ORIG_MID--AUDIO_20_R1_2009_20_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_21_R2_2009_01_ORIG_MID--AUDIO_21_R2_2009_21_R2_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_07_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_16_R2_2009_01_ORIG_MID--AUDIO_16_R2_2009_16_R2_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_21_R1_2009_04_ORIG_MID--AUDIO_21_R1_2009_21_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_05_R1_2009_01-02_ORIG_MID--AUDIO_05_R1_2009_05_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_10_R2_2009_01_ORIG_MID--AUDIO_10_R2_2009_10_R2_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_03_R1_2009_01-02_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_21_R2_2009_01_ORIG_MID--AUDIO_21_R2_2009_21_R2_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_07_R1_2009_01-03_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_05_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_16_R2_2009_01_ORIG_MID--AUDIO_16_R2_2009_16_R2_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_10_R2_2009_01_ORIG_MID--AUDIO_10_R2_2009_10_R2_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_19_R1_2009_03-04_ORIG_MID--AUDIO_19_R1_2009_19_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_09_R1_2009_05-06_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_05_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_06_R1_2009_03-07_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_06_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_02_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_01_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_04_WAV.midi
#   inflating: maestro-v3.0.0/2009/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_03_WAV.midi
#   inflating: maestro-v3.0.0/maestro-v3.0.0.csv
#   inflating: maestro-v3.0.0/README

# %%
# !pip install miditok
# Out:
# Collecting miditok
#   Downloading miditok-3.0.6.post1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from miditok) (0.34.4)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.11/dist-packages (from miditok) (2.0.2)
# Collecting symusic>=0.5.0 (from miditok)
#   Downloading symusic-0.5.8-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from miditok) (0.21.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from miditok) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (1.1.7)
# Collecting pySmartDL (from symusic>=0.5.0->miditok)
#   Downloading pySmartDL-1.3.4-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from symusic>=0.5.0->miditok) (4.3.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.16.4->miditok) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.16.4->miditok) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.16.4->miditok) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.16.4->miditok) (2025.8.3)
# Downloading miditok-3.0.6.post1-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.0/159.0 kB 2.5 MB/s eta 0:00:00
# Downloading symusic-0.5.8-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 34.4 MB/s eta 0:00:00
# Downloading pySmartDL-1.3.4-py3-none-any.whl (20 kB)
# Installing collected packages: pySmartDL, symusic, miditok
# Successfully installed miditok-3.0.6.post1 pySmartDL-1.3.4 symusic-0.5.8

# %%
# !pip install -q gdown

# %%
import os
import shutil
from pathlib import Path
import os
import numpy as np
from IPython.display import Audio, display
from miditok import REMI, TokenizerConfig
from pathlib import Path
from miditok.data_augmentation import augment_dataset
from miditok.utils import split_files_for_training
from random import shuffle
import json
from tqdm import tqdm
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

# %%
destination_folder = "dataset_midi"
os.makedirs(destination_folder, exist_ok=True)

midi_paths = list(Path(dataset_path).resolve().glob("**/*.mid")) + \
             list(Path(dataset_path).resolve().glob("**/*.midi"))

print(f"Trovati {len(midi_paths)} file MIDI.")

for midi_path in midi_paths:
    filename = os.path.basename(midi_path)
    destination_path = os.path.join(destination_folder, filename)
    shutil.copy2(midi_path, destination_path)

print("Copia completata in 'dataset_midi'.")

# Convert to relative paths
midi_paths = [Path(os.path.join(destination_folder, os.path.basename(p))) for p in midi_paths]
# Out:
# Trovati 1276 file MIDI.
# Copia completata in 'dataset_midi'.

# %% [markdown]
# ## Tokenizzazione

# %% [markdown]
# Setup iniziale

# %%
BEAT_RES = {(0, 1): 12, (1, 2): 4, (2, 4): 2, (4, 8): 1}
TOKENIZER_PARAMS = {
    "pitch_range": (21, 109),
    "beat_res": BEAT_RES,
    "num_velocities": 3,
    "special_tokens": ["BOS", "EOS"],
    "use_chords": True,
    "use_rests": True,
    "use_tempos": True,
    "num_tempos": 8,
    "tempo_range": (50, 200),
}

# %% [markdown]
# Carica file MIDI

# %%
midi_dir = Path(destination_folder)
midis = list(midi_dir.glob("**/*.mid")) + list(midi_dir.glob("**/*.midi"))

if not midis:
    raise FileNotFoundError("Nessun file MIDI trovato in 'dataset_midi'.")

# %% [markdown]
# Train o carica il tokenizer

# %%
config = TokenizerConfig(**TOKENIZER_PARAMS)

tokenizer = REMI(config)

vocab_size = 5000
tokenizer.train(vocab_size=vocab_size, files_paths=midis)
processed = [Path(f"{s}") for s in midis]
print(len(processed))
# Out:
# 1276

# %%
tokenizer.save("tokenizerMIDI")

# %% [markdown]
# Tokenizza i file MIDI

# %% [markdown]
# dataset preparation

# %%
# Assicurati che la directory base sia un Path assoluto
base_dir = Path("/content/dataset_midi").resolve()

# Ottieni tutti i file MIDI come path assoluti
midis = list(base_dir.glob("**/*.mid")) + list(base_dir.glob("**/*.midi"))
midis = [midi.resolve() for midi in midis]

# Suddivisione in train/valid/test
total_num_files = len(midis)
num_files_valid = round(total_num_files * 0.15)
num_files_test = round(total_num_files * 0.15)

shuffle(midis)

midi_paths_valid = midis[:num_files_valid]
midi_paths_test = midis[num_files_valid:num_files_valid + num_files_test]
midi_paths_train = midis[num_files_valid + num_files_test:]

# Chunk e augment
for files_paths, subset_name in (
    (midi_paths_train, "train"),
    (midi_paths_valid, "valid")
):
    subset_chunks_dir = Path(f"Maestro_{subset_name}")

    split_files_for_training(
        files_paths=files_paths,
        tokenizer=tokenizer,
        save_dir=subset_chunks_dir,
        max_seq_len=1024,
        num_overlap_bars=2,
    )

    augment_dataset(
        subset_chunks_dir,
        pitch_offsets=[-12, 12],
        velocity_offsets=[-3, 3],
        duration_offsets=[-0.5, 0.5],
    )

# Rileggi i file MIDI già chunkati e augmentati per ciascun subset
midi_paths_train = list(Path("Maestro_train").glob("**/*.mid")) + list(Path("Maestro_train").glob("**/*.midi"))
midi_paths_valid = list(Path("Maestro_valid").glob("**/*.mid")) + list(Path("Maestro_valid").glob("**/*.midi"))
# Out:
# Splitting music files (Maestro_train): 100%|██████████| 894/894 [00:05<00:00, 161.22it/s]
# Performing data augmentation: 100%|██████████| 8549/8549 [00:21<00:00, 400.39it/s]
# Splitting music files (Maestro_valid): 100%|██████████| 191/191 [00:02<00:00, 91.50it/s]
# Performing data augmentation: 100%|██████████| 1852/1852 [00:04<00:00, 406.03it/s]

# %% [markdown]
# tokenization

# %%
def midi_valid(midi) -> bool:
    if any(ts.numerator != 4 for ts in midi.time_signature_changes):
        return False  # time signature different from 4/*, 4 beats per bar
    return True

if os.path.exists("tokenized"):
  shutil.rmtree("tokenized")

for dir in ("train", "valid"):
    tokenizer.tokenize_dataset(
        Path(f"Maestro_{dir}").resolve(),
        Path(f"tokenized_{dir}").resolve(),
        midi_valid,
    )
# Out:
# Tokenizing music files (content/tokenized_train): 100%|██████████| 51073/51073 [21:40<00:00, 39.28it/s]
# Tokenizing music files (content/tokenized_valid): 100%|██████████| 11162/11162 [04:41<00:00, 39.64it/s]

# %%
# !zip -r tokenized_train.zip tokenized_train
# !zip -r tokenized_valid.zip tokenized_valid
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_7#d240.json (deflated 70%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav_0#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_2#p12.json (deflated 65%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_15_R1_2013_wav--4_5#p12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_16_R2_2009_01_ORIG_MID--AUDIO_16_R2_2009_16_R2_2009_01_WAV_4#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav_8#d-240.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--1_3#v-3.json (deflated 62%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1_4#p-12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--2_4#d-240.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_11_R1_2013_wav--1_0#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_25#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_15#p12.json (deflated 62%)
#   adding: tokenized_valid/ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--1_1.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--2_10#v3.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--2_3#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav_4.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_13#p12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_02_Track02_wav_1#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_01_Track01_wav_5#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_04_WAV_10.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_24#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_11.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV_2#d-192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_14#v-3.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_15_R2_2013_wav--1_7#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_6#p12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_31#p12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--4_8#d-240.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_02_Track02_wav_3#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav_7.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_03_Track03_wav_1.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_2.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_21_R1_2015_wav--5_6#p-12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_7#v3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--3_4#p-12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1_9#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_14#p12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R1_2009_01-02_ORIG_MID--AUDIO_05_R1_2009_05_R1_2009_01_WAV_2#d192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MID--AUDIO_11_R1_2008_wav--2_2#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_31.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--3_0#d192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1_8#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_12#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_14.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_9#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_20_R1_2006_01-04_ORIG_MID--AUDIO_20_R1_2006_01_Track01_wav_12#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_10_R2_2009_01_ORIG_MID--AUDIO_10_R2_2009_10_R2_2009_02_WAV_3#d-192.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_7#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav_11#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_14_R1_2014_wav--1_8#d-192.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--4_8#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_3#v-3.json (deflated 62%)
#   adding: tokenized_valid/ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_19_R2_2013_wav--4_3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_06_Track06_wav_5#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_2#d192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav_0.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_17_R1_2013_wav--1_0#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_22_R1_2015_wav--1_2#p-12.json (deflated 61%)
#   adding: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_7#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--3_2#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2_1#d240.json (deflated 67%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1_12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_01_WAV_10#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav_14.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav_5#v-3.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_4#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_21#d-192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--3_6#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--4_8#p12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_10_Track10_wav_0#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_2#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_03_R1_2014_wav--5_2#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_9#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_03_R2_2015_wav--1_0#p-12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R2-D1_08_Track08_wav_3#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--2_3#p12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_052_PIANO052_MID--AUDIO-split_07-06-17_Piano-e_3-03_wav--3_1#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--4_5#p12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_26#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_01_Track01_wav_1#d192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_8#p12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_02_Track02_wav_10#d-192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_10.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav_6.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_17_R1_2014_wav--1_2#d192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_08_Track08_wav_2#d240.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav_0.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_02_Track02_wav_7#d-192.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--1_11#d-240.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav_13#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav_16#d-192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_7#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--2_1#d240.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_18#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav_10#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_19#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--1_2#p12.json (deflated 65%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_11_R1_2013_wav--1_0.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--4_3#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_9.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--4_1.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_04_WAV_5#p-12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_058_PIANO058_MID--AUDIO-split_07-07-17_Piano-e_2-02_wav--2_1#v-3.json (deflated 65%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--3_9#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_0.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_0#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav_10#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_21#d192.json (deflated 65%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_6#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_14_R1_2014_wav--1_2.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--1_8#d240.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4_7.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_5#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--2_5#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--5_2#d-240.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_01_Track01_wav_3#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--1_1#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_3#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_01_WAV_6#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--2_3#d240.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_04_WAV_5#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_7#p12.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_11#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_19#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_15_Track15_wav_1#v-3.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_3#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_01_Track01_wav_11#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--1_3#p-12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_01_Track01_wav_8#d240.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--4_2#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_20.json (deflated 61%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav_2#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--4_5.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_14#p-12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_18#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav_4.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_14.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_03_Track03_wav_1#d-240.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--1_1#v-3.json (deflated 66%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--2_2.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_01_Track01_wav_10#d192.json (deflated 69%)
#   adding: tokenized_valid/MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--5_2#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_24#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_20#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--2_2#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_06_Track06_wav_1#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_04_WAV_10#p12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1_6#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_18#v-3.json (deflated 61%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1_7#d192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_11#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_9#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_03_Track03_wav_2.json (deflated 62%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_0#v3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav_9.json (deflated 66%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_30#d192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--2_3#d240.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_7#d192.json (deflated 69%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1_3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav_10#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_01_Track01_wav_8#d-192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_047_PIANO047_MID--AUDIO-split_07-06-17_Piano-e_2-04_wav--4_11#v-3.json (deflated 61%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_7#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4_5.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4_1.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_5#v3.json (deflated 62%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--3_5#p12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_16.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_15#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_04_Track04_wav_8#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav_0#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--1_9.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_20#d240.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--2_1#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav_7#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3_12#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_2.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--2_1#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav_0#p12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_10_R1_2011_MID--AUDIO_R1-D4_02_Track02_wav_6#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_10_Track10_wav_4#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_9#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_04_WAV_5#d192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_04_WAV_6#p-12.json (deflated 62%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_R1_2013_wav--5_3#v-3.json (deflated 65%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_7#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_8#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--1_9#d240.json (deflated 67%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--3_5#p-12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_14#d192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV_4#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_14#d192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--4_4#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--1_2#d240.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--1_3#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_4#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--1_3#d240.json (deflated 69%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--4_6#d240.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_25#d192.json (deflated 67%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_13_R1_2013_wav--4_3#d192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--3_0.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_047_PIANO047_MID--AUDIO-split_07-06-17_Piano-e_2-04_wav--4_11.json (deflated 61%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_11#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_10_Track10_wav_10#d-240.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--3_4#d192.json (deflated 68%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_5#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_04_Track04_wav_0#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_1#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_5.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_04_WAV_4#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_03_WAV_0#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_08_Track08_wav_4#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--3_2.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_0.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav_1#v3.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--3_5#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_14#v-3.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_15_R1_2013_wav--4_2#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav_1#p-12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_18#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_14_Track14_wav_3#d-192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_8#p12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav_1#d-192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_9#v3.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_19_R2_2013_wav--4_5#p12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--4_9#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_04_WAV_3#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_12_Track12_wav_1#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_24#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_25#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav_9#p-12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_02_WAV_2#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_3#d-240.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--7_0#d192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_10_Track10_wav_5#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_059_PIANO059_MID--AUDIO-split_07-07-17_Piano-e_2-03_wav--1_1#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--1_3#d-240.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_15#d192.json (deflated 69%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_6.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_02_Track02_wav_4#d192.json (deflated 70%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav_18#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_12_Track12_wav_1#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_10_Track10_wav_0#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_14_Track14_wav_1#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_11#d-240.json (deflated 65%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_3#d-192.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1_1.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1_3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_04_Track04_wav_6.json (deflated 61%)
#   adding: tokenized_valid/MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--1_1#d-240.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--3_3#d-192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4_7#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV_0#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_17_R1_2008_01-04_ORIG_MID--AUDIO_17_R1_2008_wav--1_0#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_5#d-240.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--3_2#d-192.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_13_R1_2013_wav--4_2#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--1_3.json (deflated 66%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_02_R1_2013_wav--1_1#d-192.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--4_4#d192.json (deflated 69%)
#   adding: tokenized_valid/MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--4_1#d-192.json (deflated 62%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--4_4#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav_2#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav_12#d-192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_3#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--1_12.json (deflated 61%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4_2#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_02_Track02_wav_3#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_17.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_14#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--4_3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_16#v-3.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--2_2#v-3.json (deflated 62%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--3_6#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R2-D1_08_Track08_wav_1#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_02_Track02_wav_0#d-240.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--4_2#d-240.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3_2.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3_3#d-240.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_13#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_03_Track03_wav_2#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_10_R1_2014_wav--5_9#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_11#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_12#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_29#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_03_Track03_wav_5#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_23#p12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_03_WAV_2#p12.json (deflated 60%)
#   adding: tokenized_valid/MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MID--AUDIO_11_R1_2008_wav--2_1#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav_8.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_29.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--2_11#d240.json (deflated 69%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_03_Track03_wav_0#d-240.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_15#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1_4.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_13#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_08_Track08_wav_3#d240.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_01_WAV_11#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--1_3#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_10_R1_2014_wav--5_8#d192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_03_Track03_wav_4.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_10.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_04_R2_2013_wav--3_0#v3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--2_7.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_35#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_5.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_27#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_22#d192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_01_WAV_6.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav_6.json (deflated 61%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_15_R1_2013_wav--4_0#v3.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_25#v-3.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_8#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_9#p-12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_02_Track02_wav_9#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_11#p12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_02_WAV_1#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_04_R1_2015_wav--3_0#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_02_R1_2011_MID--AUDIO_R1-D1_10_Track10_wav_2#p-12.json (deflated 65%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1_11.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_16.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3_9#v-3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav_15#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_05_WAV_13.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--4_7#v3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_15_Track15_wav_1#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_5#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_11#v3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_07_Track07_wav_1#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_062_PIANO062_MID--AUDIO-split_07-07-17_Piano-e_2-07_wav--4_6#d-240.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--4_10.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_22_R1_2015_wav--4_0#d-240.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3_3#v3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--1_3#d-240.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--4_5#d240.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav_7#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_14.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav_6#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_2#d-192.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_24.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--2_10#d240.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_02_Track02_wav_5#p12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_19.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_22#d-192.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav_4.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_11_R2_2015_wav--2_1#v3.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav_2#v3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_23#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_8.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_02_Track02_wav_2#d-240.json (deflated 63%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_7#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_0#d192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_10#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--3_1.json (deflated 61%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_15#p12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--4_2#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_04_Track04_wav_0#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav_6#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_02_Track02_wav_10#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_17_R1_2008_01-04_ORIG_MID--AUDIO_17_R1_2008_wav--1_1#p12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_11_Track11_wav_5#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav_0.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav_7.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--1_3#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_6#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_01_Track01_wav_3#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav_9#d-240.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_04_WAV_0.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_5#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--2_1#v3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_06_WAV_2#p-12.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_03_Track03_wav_4#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_6#p12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_21_R2_2015_wav--2_6#v-3.json (deflated 61%)
#   adding: tokenized_valid/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_05_WAV_2#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--1_2#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_22#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_01_WAV_6#d-192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_02_WAV_3#d-192.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_21_R1_2015_wav--5_0#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_7.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_15.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_0#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_5#d-192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_20_R1_2006_01-04_ORIG_MID--AUDIO_20_R1_2006_01_Track01_wav_8#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_22#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_03_Track03_wav_11#d240.json (deflated 69%)
#   adding: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_13#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_21_R2_2015_wav--2_5#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2_7#p-12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_6#v-3.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--2_4.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_059_PIANO059_MID--AUDIO-split_07-07-17_Piano-e_2-03_wav--1_2#d-240.json (deflated 66%)
# ...
#   adding: tokenized_valid/MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--2_0#p-12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav_2#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_25.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_21_R2_2015_wav--2_7#p12.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--2_2#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_6#p-12.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_01_Track01_wav_0#v3.json (deflated 65%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--2_12.json (deflated 62%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--4_11#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_10_R1_2014_wav--5_8.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_01_Track01_wav_5#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1_7#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--2_1#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_36#p-12.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_13#d-192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--1_9#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2_7#p12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_3#v-3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_11#v-3.json (deflated 61%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_11_Track11_wav_6#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_25#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_10#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav_4#d240.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_27#d192.json (deflated 66%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--2_0#p12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav_21#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--1_7#d240.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_10#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3_2#d-240.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_31#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_02_WAV_1#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav_21#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_11_Track11_wav_5#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_32#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1_4#p12.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_04_R2_2013_wav--3_11#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_06_Track06_wav_3#v3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_4#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_15_Track15_wav_2#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_3#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_05_R1_2015_wav--1_0#d240.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_21#d192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--2_0#d-240.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--3_6#v3.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_R1_2013_wav--3_0.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_5#d240.json (deflated 65%)
#   adding: tokenized_valid/ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_10_R1_2013_wav--3_3#p12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_25#d192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav_1#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav_15.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_03_Track03_wav_9#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_02_R1_2011_MID--AUDIO_R1-D1_08_Track08_wav_2#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--3_0#p12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_17_R1_2014_wav--1_4#p12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--1_9#d240.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav_15#d192.json (deflated 67%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--3_4#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_28#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_3#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_1#d-192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--4_0#d-192.json (deflated 68%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_16#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_1#v-3.json (deflated 65%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_1#p-12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV_3#p-12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_1.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_29#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_12_Track12_wav_2#v-3.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_8#v-3.json (deflated 64%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_12#d192.json (deflated 67%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_R1_2013_wav--3_3#d-192.json (deflated 65%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1_0.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav_1#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_0#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_4#v3.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_13_R1_2013_wav--4_9.json (deflated 62%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--2_0#p12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_04_Track04_wav_1#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_1#v3.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_12.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2_8#v-3.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav_6#v-3.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_04_R2_2013_wav--3_1#d192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav_12#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_03_Track03_wav_2#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_03_Track03_wav_11#p12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_2#v3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_1#p12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_10#d-192.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--4_5#d-192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2_0#v-3.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_052_PIANO052_MID--AUDIO-split_07-06-17_Piano-e_3-03_wav--3_4#p-12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_20.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_08_Track08_wav_2#p12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_16#d240.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_19#p-12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R1_2009_01-02_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_01_WAV_8#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--2_2#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_16#d-192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_05_R1_2009_01-02_ORIG_MID--AUDIO_05_R1_2009_05_R1_2009_01_WAV_8#v3.json (deflated 62%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--2_0#p-12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--4_3#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_1.json (deflated 63%)
#   adding: tokenized_valid/ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--3_6#d-192.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV_5#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_21#d192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav_7#d-192.json (deflated 66%)
#   adding: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_04_R2_2013_wav--3_12#d-192.json (deflated 57%)
#   adding: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2_1#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_04_R1_2009_04-06_ORIG_MID--AUDIO_04_R1_2009_04_R1_2009_04_WAV_3#v-3.json (deflated 58%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_17_R1_2014_wav--1_3#v-3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_1#d192.json (deflated 68%)
#   adding: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_2#p-12.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_04_WAV_3#d192.json (deflated 67%)
#   adding: tokenized_valid/MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--4_3.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_7#d-240.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_02_WAV_0#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_9#p12.json (deflated 64%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_12#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_22#d-192.json (deflated 63%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_2#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_23#v3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--1_2#p12.json (deflated 65%)
#   adding: tokenized_valid/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_04_Track04_wav_5#d192.json (deflated 66%)
#   adding: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_12#p12.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--3_1#v-3.json (deflated 63%)
#   adding: tokenized_valid/MIDI-Unprocessed_XP_08_R1_2004_01-02_ORIG_MID--AUDIO_08_R1_2004_01_Track01_wav_5#v-3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_10_Track10_wav_11#v3.json (deflated 65%)
#   adding: tokenized_valid/ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--1_0.json (deflated 62%)
#   adding: tokenized_valid/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_06_WAV_4.json (deflated 63%)
#   adding: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_24#v3.json (deflated 64%)
#   adding: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV_5.json (deflated 63%)

# %% [markdown]
# Scaricare tokenizer addestrato e midi

# %%
# !gdown --id 1VfmfvXp8QiH10Q5VFTc_TCyKvGSthD3-
# !gdown --id 1Cnj-YhsNcj_GTGTAwjgRsBwK8fXXKZax

# !unzip tokenized_train.zip
# !unzip tokenized_valid.zip
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_7#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav_0#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_2#p12.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_15_R1_2013_wav--4_5#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_16_R2_2009_01_ORIG_MID--AUDIO_16_R2_2009_16_R2_2009_01_WAV_4#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav_8#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--1_3#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1_4#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--2_4#d-240.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_11_R1_2013_wav--1_0#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_25#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_15#p12.json
#   inflating: tokenized_valid/ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--1_1.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--2_10#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--2_3#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav_4.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_13#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_02_Track02_wav_1#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_01_Track01_wav_5#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_04_WAV_10.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_24#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_11.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV_2#d-192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_14#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_15_R2_2013_wav--1_7#v3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_6#p12.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_31#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--4_8#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_02_Track02_wav_3#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav_7.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_03_Track03_wav_1.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_2.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_21_R1_2015_wav--5_6#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_7#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--3_4#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1_9#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_14#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R1_2009_01-02_ORIG_MID--AUDIO_05_R1_2009_05_R1_2009_01_WAV_2#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MID--AUDIO_11_R1_2008_wav--2_2#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_31.json
#   inflating: tokenized_valid/MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--3_0#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1_8#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_12#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_14.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_9#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_20_R1_2006_01-04_ORIG_MID--AUDIO_20_R1_2006_01_Track01_wav_12#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_10_R2_2009_01_ORIG_MID--AUDIO_10_R2_2009_10_R2_2009_02_WAV_3#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_7#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav_11#d192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_14_R1_2014_wav--1_8#d-192.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--4_8#d-192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_3#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_19_R2_2013_wav--4_3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_06_Track06_wav_5#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_2#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav_0.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_17_R1_2013_wav--1_0#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_22_R1_2015_wav--1_2#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_7#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--3_2#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2_1#d240.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1_12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_01_WAV_10#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav_14.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav_5#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_4#d192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_21#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--3_6#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--4_8#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_10_Track10_wav_0#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_2#v3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_03_R1_2014_wav--5_2#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_9#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_03_R2_2015_wav--1_0#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R2-D1_08_Track08_wav_3#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--2_3#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_052_PIANO052_MID--AUDIO-split_07-06-17_Piano-e_3-03_wav--3_1#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--4_5#p12.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_26#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_01_Track01_wav_1#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_8#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_02_Track02_wav_10#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_10.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav_6.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_17_R1_2014_wav--1_2#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_08_Track08_wav_2#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav_0.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_02_Track02_wav_7#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--1_11#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav_13#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav_16#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_7#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--2_1#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_18#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav_10#d-192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_19#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--1_2#p12.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_11_R1_2013_wav--1_0.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--4_3#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_9.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--4_1.json
#   inflating: tokenized_valid/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_04_WAV_5#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_058_PIANO058_MID--AUDIO-split_07-07-17_Piano-e_2-02_wav--2_1#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--3_9#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_0.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_0#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav_10#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_21#d192.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_6#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_14_R1_2014_wav--1_2.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--1_8#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4_7.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_5#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--2_5#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--5_2#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_01_Track01_wav_3#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--1_1#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_3#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_01_WAV_6#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--2_3#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_04_WAV_5#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_7#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_11#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_19#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_15_Track15_wav_1#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_3#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_01_Track01_wav_11#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--1_3#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_01_Track01_wav_8#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--4_2#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_20.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav_2#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--4_5.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_14#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_18#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav_4.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_14.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_03_Track03_wav_1#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--1_1#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--2_2.json
#   inflating: tokenized_valid/MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_01_Track01_wav_10#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--5_2#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_24#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_20#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--2_2#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_06_Track06_wav_1#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_04_WAV_10#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1_6#v3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_18#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1_7#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_11#v3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_9#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_03_Track03_wav_2.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_0#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav_9.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_30#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--2_3#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_7#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1_3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav_10#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_01_Track01_wav_8#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_047_PIANO047_MID--AUDIO-split_07-06-17_Piano-e_2-04_wav--4_11#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_7#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4_5.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4_1.json
#   inflating: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_5#v3.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--3_5#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_16.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_15#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_04_Track04_wav_8#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav_0#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--1_9.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_20#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--2_1#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav_7#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3_12#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_2.json
#   inflating: tokenized_valid/MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--2_1#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav_0#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_10_R1_2011_MID--AUDIO_R1-D4_02_Track02_wav_6#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_10_Track10_wav_4#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_9#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_04_WAV_5#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_04_WAV_6#p-12.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_R1_2013_wav--5_3#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_7#v3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_8#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--1_9#d240.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--3_5#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_14#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV_4#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_14#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--4_4#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--1_2#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--1_3#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_4#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--1_3#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--4_6#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_25#d192.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_13_R1_2013_wav--4_3#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--3_0.json
#   inflating: tokenized_valid/MIDI-Unprocessed_047_PIANO047_MID--AUDIO-split_07-06-17_Piano-e_2-04_wav--4_11.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_11#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_10_Track10_wav_10#d-240.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--3_4#d192.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_5#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_04_Track04_wav_0#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_1#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_5.json
#   inflating: tokenized_valid/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_04_WAV_4#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_03_WAV_0#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_08_Track08_wav_4#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--3_2.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_0.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav_1#v3.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--3_5#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_14#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_15_R1_2013_wav--4_2#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav_1#p-12.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_18#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_14_Track14_wav_3#d-192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_8#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav_1#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_12.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_9#v3.json
#   inflating: tokenized_valid/ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_19_R2_2013_wav--4_5#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--4_9#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_04_WAV_3#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_12_Track12_wav_1#v3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_24#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_25#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav_9#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_02_WAV_2#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_3#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--7_0#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_10_Track10_wav_5#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_059_PIANO059_MID--AUDIO-split_07-07-17_Piano-e_2-03_wav--1_1#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--1_3#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_15#d192.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_6.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_02_Track02_wav_4#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav_18#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_12_Track12_wav_1#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_10_Track10_wav_0#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_14_Track14_wav_1#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_11#d-240.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_3#d-192.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1_1.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1_3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_04_Track04_wav_6.json
#   inflating: tokenized_valid/MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--1_1#d-240.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--3_3#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4_7#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV_0#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_17_R1_2008_01-04_ORIG_MID--AUDIO_17_R1_2008_wav--1_0#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_5#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--3_2#d-192.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_13_R1_2013_wav--4_2#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--1_3.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_02_R1_2013_wav--1_1#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--4_4#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--4_1#d-192.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--4_4#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav_2#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav_12#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_3#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--1_12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4_2#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_02_Track02_wav_3#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_17.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_14#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--4_3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_16#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--2_2#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--3_6#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R2-D1_08_Track08_wav_1#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_02_Track02_wav_0#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--4_2#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3_2.json
#   inflating: tokenized_valid/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3_3#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_13#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_03_Track03_wav_2#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_10_R1_2014_wav--5_9#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_11#d192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_12#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_29#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_03_Track03_wav_5#v3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_23#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_03_WAV_2#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MID--AUDIO_11_R1_2008_wav--2_1#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav_8.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_29.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--2_11#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_03_Track03_wav_0#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_15#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1_4.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_13#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_08_Track08_wav_3#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_01_WAV_11#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--1_3#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_10_R1_2014_wav--5_8#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_03_Track03_wav_4.json
#   inflating: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_10.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_04_R2_2013_wav--3_0#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--2_7.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_35#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_5.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_27#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_22#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_01_WAV_6.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav_6.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_15_R1_2013_wav--4_0#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_25#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_8#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_9#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_02_Track02_wav_9#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_11#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_02_WAV_1#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_04_R1_2015_wav--3_0#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_02_R1_2011_MID--AUDIO_R1-D1_10_Track10_wav_2#p-12.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1_11.json
#   inflating: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_16.json
#   inflating: tokenized_valid/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3_9#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav_15#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_05_WAV_13.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--4_7#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_15_Track15_wav_1#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_5#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_11#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_07_Track07_wav_1#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_062_PIANO062_MID--AUDIO-split_07-07-17_Piano-e_2-07_wav--4_6#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--4_10.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_22_R1_2015_wav--4_0#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3_3#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--1_3#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--4_5#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav_7#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_14.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav_6#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_2#d-192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_24.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--2_10#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_02_Track02_wav_5#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_19.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_22#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav_4.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_11_R2_2015_wav--2_1#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav_2#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_23#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_8.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_02_Track02_wav_2#d-240.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_7#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_0#d192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_10#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--3_1.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_15#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--4_2#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_04_Track04_wav_0#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav_6#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_02_Track02_wav_10#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_17_R1_2008_01-04_ORIG_MID--AUDIO_17_R1_2008_wav--1_1#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_11_Track11_wav_5#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav_0.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav_7.json
#   inflating: tokenized_valid/ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--1_3#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_6#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_01_Track01_wav_3#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav_9#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_04_WAV_0.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_5#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--2_1#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_06_WAV_2#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_03_Track03_wav_4#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_6#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_21_R2_2015_wav--2_6#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_05_WAV_2#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--1_2#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_22#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_01_WAV_6#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_02_WAV_3#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_21_R1_2015_wav--5_0#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_7.json
#   inflating: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_15.json
#   inflating: tokenized_valid/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV_0#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_5#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_20_R1_2006_01-04_ORIG_MID--AUDIO_20_R1_2006_01_Track01_wav_8#v3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_22#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_03_Track03_wav_11#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_13#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_21_R2_2015_wav--2_5#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2_7#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_6#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--2_4.json
#   inflating: tokenized_valid/MIDI-Unprocessed_059_PIANO059_MID--AUDIO-split_07-07-17_Piano-e_2-03_wav--1_2#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_04_Track04_wav_8#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_15#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_02_WAV_4#d-192.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_18_R1_2013_wav--5_2#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1_9#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_05_WAV_10#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_6#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav_2#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--2_0#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--2_5#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_04_WAV_10#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_13#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_15_Track15_wav_0#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_13_Track13_wav_5#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R2-D1_08_Track08_wav_0.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_6#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--4_6#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--4_1.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_03_WAV_1#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_05_WAV_12#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R1_2009_01-02_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_01_WAV_10#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--1_8#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_0.json
#   inflating: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_10#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_22#p12.json
#   inflating: tokenized_valid/ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_19_R2_2013_wav--4_2#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_01_WAV_11#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_12#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_10_R2_2009_01_ORIG_MID--AUDIO_10_R2_2009_10_R2_2009_02_WAV_1.json
#   inflating: tokenized_valid/ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--1_3#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_04_WAV_8#p12.json
#   inflating: tokenized_valid/ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--1_0#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_05_WAV_7#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_04_Track04_wav_6#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_16_R2_2009_01_ORIG_MID--AUDIO_16_R2_2009_16_R2_2009_01_WAV_6#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_1#v-3.json
# ...
#   inflating: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_13#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_10#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--4_4.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_14_R1_2014_wav--1_1.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--2_0#d240.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_7#d-192.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--2_8#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav_16#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--2_4#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_22.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1_0#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--2_10#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--2_0#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav_2#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_25.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_21_R2_2015_wav--2_7#p12.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--2_2#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_6#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_01_Track01_wav_0#v3.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--2_12.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--4_11#d192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_10_R1_2014_wav--5_8.json
#   inflating: tokenized_valid/MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_01_Track01_wav_5#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1_7#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--2_1#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_36#p-12.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_13#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--1_9#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2_7#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_3#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_11#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_11_Track11_wav_6#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_25#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_10#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav_4#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_27#d192.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--2_0#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav_21#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--1_7#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_10#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3_2#d-240.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_31#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_02_WAV_1#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav_21#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_11_Track11_wav_5#p-12.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_32#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1_4#p12.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_04_R2_2013_wav--3_11#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_06_Track06_wav_3#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_4#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_15_Track15_wav_2#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_3#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_05_R1_2015_wav--1_0#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_21#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--2_0#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--3_6#v3.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_R1_2013_wav--3_0.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_5#d240.json
#   inflating: tokenized_valid/ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_10_R1_2013_wav--3_3#p12.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_25#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav_1#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav_15.json
#   inflating: tokenized_valid/MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_03_Track03_wav_9#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_02_R1_2011_MID--AUDIO_R1-D1_08_Track08_wav_2#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--3_0#p12.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_17_R1_2014_wav--1_4#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--1_9#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav_15#d192.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--3_4#d192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav_28#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav_3#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_13_R1_2009_04_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_04_WAV_1#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--4_0#d-192.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_16#v3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_1#v-3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_1#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV_3#p-12.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_1.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_29#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_12_Track12_wav_2#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_8#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1_12#d192.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_R1_2013_wav--3_3#d-192.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1_0.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav_1#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_0#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_4#v3.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_13_R1_2013_wav--4_9.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--2_0#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_04_Track04_wav_1#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav_1#v3.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4_12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2_8#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav_6#v-3.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_04_R2_2013_wav--3_1#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav_12#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_03_Track03_wav_2#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_03_Track03_wav_11#p12.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_2#v3.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5_1#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_10#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--4_5#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2_0#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_052_PIANO052_MID--AUDIO-split_07-06-17_Piano-e_3-03_wav--3_4#p-12.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_20.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_08_Track08_wav_2#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_16#d240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_19#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R1_2009_01-02_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_01_WAV_8#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--2_2#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav_16#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_05_R1_2009_01-02_ORIG_MID--AUDIO_05_R1_2009_05_R1_2009_01_WAV_8#v3.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--2_0#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--4_3#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_1.json
#   inflating: tokenized_valid/ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--3_6#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV_5#d-192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_21#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav_7#d-192.json
#   inflating: tokenized_valid/ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_04_R2_2013_wav--3_12#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2_1#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_04_R1_2009_04-06_ORIG_MID--AUDIO_04_R1_2009_04_R1_2009_04_WAV_3#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_12.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_17_R1_2014_wav--1_3#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_1#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1_2#p-12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_04_WAV_3#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--4_3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3_7#d-240.json
#   inflating: tokenized_valid/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_02_WAV_0#d-192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav_9#p12.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_17_R2_2014_wav_12#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_22#d-192.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav_2#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav_23#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--1_2#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_04_Track04_wav_5#d192.json
#   inflating: tokenized_valid/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV_12#p12.json
#   inflating: tokenized_valid/MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--3_1#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_XP_08_R1_2004_01-02_ORIG_MID--AUDIO_08_R1_2004_01_Track01_wav_5#v-3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_10_Track10_wav_11#v3.json
#   inflating: tokenized_valid/ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--1_0.json
#   inflating: tokenized_valid/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_06_WAV_4.json
#   inflating: tokenized_valid/MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_04_R2_2014_wav_24#v3.json
#   inflating: tokenized_valid/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV_5.json

# %%
# !gdown --id 12der1lMHfMyMbGWImONehL_43AoECyzB
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=12der1lMHfMyMbGWImONehL_43AoECyzB
# To: /content/tokenizer (2).json
# 100% 271k/271k [00:00<00:00, 127MB/s]

# %%
tokenizer = REMI(params="tokenizer (2).json")

# %%
def read_json(path: str) -> dict:
  with open(path, "r") as f:
    return json.load(f)

def read_json_files(json_file_paths):
    objects = []

    for file_path in tqdm(json_file_paths):
        try:
            objects.append(read_json(file_path))
        except FileNotFoundError:
            print(f"Error: File not found - {file_path}")
            return []
        except json.JSONDecodeError:
            print(f"Error decoding JSON in file: {file_path}")
            return []
    return objects

tokenized_train = list(Path("tokenized_train").resolve().glob("**/*.json"))
data_objects_train = read_json_files(tokenized_train)

tokenized_valid = list(Path("tokenized_valid").resolve().glob("**/*.json"))
data_objects_valid = read_json_files(tokenized_valid)



if data_objects_train and data_objects_valid:
    print(f"\nSuccessfully read {len(data_objects_train)} training JSON files.")
    print(f"Successfully read {len(data_objects_valid)} validation JSON files.")
else:
    print("Error reading JSON files.")
# Out:
# 100%|██████████| 51073/51073 [00:07<00:00, 6581.18it/s]
# 100%|██████████| 11162/11162 [00:01<00:00, 7479.90it/s]
# Successfully read 51073 training JSON files.
# Successfully read 11162 validation JSON files.

# %%
encoded_train = [np.array(song["ids"][0]) for song in data_objects_train]
encoded_valid = [np.array(song["ids"][0]) for song in data_objects_valid]
all_ids_train = np.concatenate(encoded_train)
all_ids_valid = np.concatenate(encoded_valid)

all_ids_train = all_ids_train.astype(dtype=np.int32)
all_ids_valid = all_ids_valid.astype(dtype=np.int32)

# %% [markdown]
# ## GAN model

# %%
class Generator(nn.Module):
    def __init__(self, noise_dim: int, hidden_dim: int, output_length: int):
        super().__init__()

        # Livelli fully-connected
        self.input_layer = nn.Linear(noise_dim, hidden_dim * 8)
        self.hidden_layer1 = nn.Linear(hidden_dim * 8, hidden_dim * 4)
        self.hidden_layer2 = nn.Linear(hidden_dim * 4, hidden_dim * 2)
        self.hidden_layer3 = nn.Linear(hidden_dim * 2, hidden_dim)
        self.output_layer = nn.Linear(hidden_dim, output_length)

        # Attivazioni e dropout
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.4)

    def forward(self, noise_vector: torch.Tensor) -> torch.Tensor:
        x = self.relu(self.input_layer(noise_vector))
        x = self.dropout(self.relu(self.hidden_layer1(x)))
        x = self.dropout(self.relu(self.hidden_layer2(x)))
        x = self.dropout(self.relu(self.hidden_layer3(x)))
        x = self.output_layer(x)
        return torch.tanh(x)

# %%
class Generator(nn.Module):
    def __init__(self, noise_dim: int, hidden_dim: int, output_length: int):
        super().__init__()

        # Livelli fully-connected
        self.input_layer = nn.Linear(noise_dim, hidden_dim * 16)
        self.hidden_layer1 = nn.Linear(hidden_dim * 16, hidden_dim * 8)
        self.hidden_layer2 = nn.Linear(hidden_dim * 8, hidden_dim * 4)
        self.hidden_layer3 = nn.Linear(hidden_dim * 4, hidden_dim * 2)
        self.hidden_layer4 = nn.Linear(hidden_dim * 2, hidden_dim)
        self.output_layer = nn.Linear(hidden_dim, output_length)

        # Attivazioni e dropout
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.4)

    def forward(self, noise_vector: torch.Tensor) -> torch.Tensor:
        x = self.relu(self.input_layer(noise_vector))
        x = self.dropout(self.relu(self.hidden_layer1(x)))
        x = self.dropout(self.relu(self.hidden_layer2(x)))
        x = self.dropout(self.relu(self.hidden_layer3(x)))
        x = self.dropout(self.relu(self.hidden_layer4(x)))
        x = self.output_layer(x)
        return torch.tanh(x)

# %%
class Generator(nn.Module):
    def __init__(self, noise_dim: int, hidden_dim: int, output_length: int):
        super().__init__()

        # Livelli fully-connected
        self.input_layer = nn.Linear(noise_dim, hidden_dim * 32)
        self.hidden_layer1 = nn.Linear(hidden_dim * 32, hidden_dim * 16)
        self.hidden_layer2 = nn.Linear(hidden_dim * 16, hidden_dim * 8)
        self.hidden_layer3 = nn.Linear(hidden_dim * 8, hidden_dim * 4)
        self.hidden_layer4 = nn.Linear(hidden_dim * 4, hidden_dim * 2)
        self.hidden_layer5 = nn.Linear(hidden_dim * 2, hidden_dim)
        self.output_layer = nn.Linear(hidden_dim, output_length)

        # Attivazioni e dropout
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.4)

    def forward(self, noise_vector: torch.Tensor) -> torch.Tensor:
        x = self.relu(self.input_layer(noise_vector))
        x = self.dropout(self.relu(self.hidden_layer1(x)))
        x = self.dropout(self.relu(self.hidden_layer2(x)))
        x = self.dropout(self.relu(self.hidden_layer3(x)))
        x = self.dropout(self.relu(self.hidden_layer4(x)))
        x = self.dropout(self.relu(self.hidden_layer5(x)))
        x = self.output_layer(x)
        return torch.tanh(x)

# %% [markdown]
# Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, input_length: int, hidden_dim: int):
        super().__init__()

        # Livelli fully-connected
        self.input_layer = nn.Linear(input_length, hidden_dim * 2)
        self.hidden_layer1 = nn.Linear(hidden_dim * 2, hidden_dim * 4)
        self.hidden_layer2 = nn.Linear(hidden_dim * 4, hidden_dim * 8)
        self.output_layer = nn.Linear(hidden_dim * 8, 1)

        # Attivazioni e dropout
        self.leaky_relu = nn.LeakyReLU(negative_slope=0.2)
        self.dropout = nn.Dropout(0.4)

    def forward(self, sequence: torch.Tensor) -> torch.Tensor:
        x = self.leaky_relu(self.input_layer(sequence))
        x = self.dropout(self.leaky_relu(self.hidden_layer1(x)))
        x = self.dropout(self.leaky_relu(self.hidden_layer2(x)))
        x = self.output_layer(x)
        return x

# %%
class Discriminator(nn.Module):
    def __init__(self, input_length: int, hidden_dim: int):
        super().__init__()

        # Livelli fully-connected
        self.input_layer = nn.Linear(input_length, hidden_dim * 2)
        self.hidden_layer1 = nn.Linear(hidden_dim * 2, hidden_dim * 4)
        self.hidden_layer2 = nn.Linear(hidden_dim * 4, hidden_dim * 8)
        self.hidden_layer3 = nn.Linear(hidden_dim * 8, hidden_dim * 16)
        self.output_layer = nn.Linear(hidden_dim * 16, 1)

        # Attivazioni e dropout
        self.leaky_relu = nn.LeakyReLU(negative_slope=0.2)
        self.dropout = nn.Dropout(0.4)

    def forward(self, sequence: torch.Tensor) -> torch.Tensor:
        x = self.leaky_relu(self.input_layer(sequence))
        x = self.dropout(self.leaky_relu(self.hidden_layer1(x)))
        x = self.dropout(self.leaky_relu(self.hidden_layer2(x)))
        x = self.dropout(self.leaky_relu(self.hidden_layer3(x)))
        x = self.output_layer(x)
        return x

# %%
class Discriminator(nn.Module):
    def __init__(self, input_length: int, hidden_dim: int):
        super().__init__()

        # Livelli fully-connected
        self.input_layer = nn.Linear(input_length, hidden_dim * 2)
        self.hidden_layer1 = nn.Linear(hidden_dim * 2, hidden_dim * 4)
        self.hidden_layer2 = nn.Linear(hidden_dim * 4, hidden_dim * 8)
        self.hidden_layer3 = nn.Linear(hidden_dim * 8, hidden_dim * 16)
        self.hidden_layer4 = nn.Linear(hidden_dim * 26, hidden_dim * 32)
        self.output_layer = nn.Linear(hidden_dim * 32, 1)

        # Attivazioni e dropout
        self.leaky_relu = nn.LeakyReLU(negative_slope=0.2)
        self.dropout = nn.Dropout(0.4)

    def forward(self, sequence: torch.Tensor) -> torch.Tensor:
        x = self.leaky_relu(self.input_layer(sequence))
        x = self.dropout(self.leaky_relu(self.hidden_layer1(x)))
        x = self.dropout(self.leaky_relu(self.hidden_layer2(x)))
        x = self.dropout(self.leaky_relu(self.hidden_layer3(x)))
        x = self.dropout(self.leaky_relu(self.hidden_layer4(x)))
        x = self.output_layer(x)
        return x

# %%
vocab_size = len(tokenizer)
seq_length = 512
noise_dim = 512
hidden_dim = 1536
batch_size = 128

generator_config = {
    "noise_dim"  : noise_dim,
    "hidden_dim" : hidden_dim,
    "output_length" : seq_length
}


discriminator_config = {
    "input_length" : seq_length,
    "hidden_dim" : hidden_dim
}

generator = Generator(**generator_config)
discriminator = Discriminator(**discriminator_config)

gan_params = {
    "generator"                : generator,
    "discriminator"            : discriminator,
    "noise_dim"                : noise_dim,
    "sequence_length"          : seq_length,
    "tokenizer"                : tokenizer,
}

# %% [markdown]
# GAN

# %%
class GAN:
    def __init__(
        self,
        generator: nn.Module,
        discriminator: nn.Module,
        noise_dim: int,
        sequence_length: int,
        tokenizer,
        loss_fn: nn.Module = nn.BCEWithLogitsLoss(),
    ):
        """
        Classe GAN per addestrare un generatore e discriminatore.
        """
        self.generator = generator
        self.discriminator = discriminator
        self.noise_dim = noise_dim
        self.sequence_length = sequence_length
        self.loss_fn = loss_fn
        self.tokenizer = tokenizer
        self.vocab_size = len(tokenizer)

        # Ottimizzatori
        self.generator_optimizer = torch.optim.Adam(
            self.generator.parameters(), lr=0.00005, betas=(0.5, 0.999)
        )
        self.discriminator_optimizer = torch.optim.Adam(
            self.discriminator.parameters(), lr=0.00005, betas=(0.5, 0.999)
        )

        # Inizializzazione pesi
        self.generator.apply(self._init_weights)
        self.discriminator.apply(self._init_weights)

    def _init_weights(self, layer):
        """Inizializza i pesi dei layer lineari e conv1d."""
        if isinstance(layer, (nn.Linear, nn.Conv1d)):
            nn.init.xavier_uniform_(layer.weight)
            if layer.bias is not None:
                nn.init.zeros_(layer.bias)

    def _sample_noise(self, batch_size: int, device: torch.device) -> torch.Tensor:
        """Genera rumore casuale come input per il generatore."""
        return torch.randn(batch_size, self.noise_dim, device=device)

    def _generator_train_step(self, batch_size: int, device: torch.device) -> float:
        """Esegue un passo di training per il generatore."""
        self.generator.zero_grad()

        noise = self._sample_noise(batch_size, device)
        fake_data = self.generator(noise)
        fake_predictions = self.discriminator(fake_data)

        loss_g = -torch.mean(fake_predictions)

        if not (torch.isnan(loss_g) or torch.isinf(loss_g)):
            loss_g.backward()
            torch.nn.utils.clip_grad_norm_(self.generator.parameters(), max_norm=1.0)
            self.generator_optimizer.step()
        else:
            print("⚠ NaN o Inf rilevato nella loss del generatore.")

        return loss_g.item()

    def _discriminator_train_step(
        self, batch_size: int, real_data: torch.Tensor, device: torch.device
    ) -> float:
        """Esegue un passo di training per il discriminatore."""
        self.discriminator.zero_grad()

        noise = self._sample_noise(batch_size, device)
        fake_data = self.generator(noise)

        real_predictions = self.discriminator(real_data)
        fake_predictions = self.discriminator(fake_data)

        real_labels = torch.ones_like(real_predictions)
        fake_labels = torch.zeros_like(fake_predictions)

        loss_real = self.loss_fn(real_predictions, real_labels)
        loss_fake = self.loss_fn(fake_predictions, fake_labels)

        loss_d = loss_real + loss_fake

        if not (torch.isnan(loss_d) or torch.isinf(loss_d)):
            loss_d.backward()
            self.discriminator_optimizer.step()
        else:
            print("⚠ NaN o Inf rilevato nella loss del discriminatore.")

        return loss_d.item()

    def _train_batch(
        self, batch_size: int, real_data: torch.Tensor, device: torch.device,
        generator_steps: int, discriminator_steps: int
    ):
        """Esegue un batch di training alternando generator e discriminator."""
        discriminator_losses = [
            self._discriminator_train_step(batch_size, real_data, device)
            for _ in range(discriminator_steps)
        ]
        generator_losses = [
            self._generator_train_step(batch_size, device)
            for _ in range(generator_steps)
        ]
        return np.mean(discriminator_losses), np.mean(generator_losses)

    def train(
        self,
        dataloader,
        epochs: int,
        device: torch.device,
        loss_delta: float = 0.7,
        steps_each_print: int = 5,
        advantage_steps: int = 2,
        alternate_training: bool = False,
        generator_steps: int = 1,
        discriminator_steps: int = 1,
    ):
        """
        Addestra la GAN su un dataloader.
        """
        print(f"🚀 Avvio training per {epochs} epoche")
        self.generator.to(device).train()
        self.discriminator.to(device).train()

        all_d_losses = []
        all_g_losses = []

        for epoch in range(epochs):
            pbar = tqdm(total=len(dataloader), desc=f"Epoch {epoch+1}/{epochs}")
            for step, real_batch in enumerate(dataloader):
                batch_size = real_batch.size(0)
                real_batch = real_batch.to(device)

                d_loss, g_loss = self._train_batch(
                    batch_size, real_batch, device, generator_steps, discriminator_steps
                )
                all_d_losses.append(d_loss)
                all_g_losses.append(g_loss)

                if alternate_training:
                    if g_loss - d_loss > loss_delta:
                        generator_steps, discriminator_steps = advantage_steps, 1
                    elif d_loss - g_loss > loss_delta:
                        discriminator_steps, generator_steps = advantage_steps, 1
                    else:
                        generator_steps, discriminator_steps = 1, 1

                if (step + 1) % steps_each_print == 0:
                    desc = f"D Loss: {d_loss:.4f}, G Loss: {g_loss:.4f}"
                    if generator_steps != 1 or discriminator_steps != 1:
                        desc += f" | D Steps: {discriminator_steps}, G Steps: {generator_steps}"
                    pbar.set_description(desc)
                pbar.update(1)

            pbar.close()
            print(f"Epoch {epoch+1}/{epochs} | D Loss: {d_loss:.4f} | G Loss: {g_loss:.4f}")

        return all_d_losses, all_g_losses

    def save_generator(self, filepath: str):
        """Salva il generatore su disco."""
        torch.save(self.generator.state_dict(), filepath)

    def save_discriminator(self, filepath: str):
        """Salva i pesi del discriminatore su disco."""
        torch.save(self.discriminator.state_dict(), filepath)

    def predict(self, n_samples: int, device: torch.device):
        """Genera output dal generatore sotto forma di array NumPy."""
        noise = self._sample_noise(n_samples, device)
        return self.generator(noise).cpu().detach().numpy()

    def generate_midi(self, n_samples: int, output_prefix: str, device: torch.device):
        """Genera e salva file MIDI a partire dal generatore."""
        predictions = self.predict(n_samples, device)
        midpoint = self.vocab_size // 2
        predictions = [x * midpoint + midpoint for x in predictions]

        for i, pred in enumerate(predictions):
            pred_tokens = pred.astype(np.int32)
            pred_tokens[pred_tokens == self.vocab_size] = 0
            try:
                decoded = self.tokenizer.decode([pred_tokens])
                decoded.dump_midi(f"{output_prefix}_{i}.mid")
            except Exception as e:
                print(f"Errore nella generazione MIDI: {e}")

# %%
class TokenDataset(Dataset):
    """Dataset di sequenze di token normalizzate per addestramento GAN."""
    def __init__(self, sequences):
        self.sequences = sequences

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        return torch.tensor(self.sequences[idx], dtype=torch.float32)


def normalize_data(token_array, vocab_size: int, interval=(-1, 1)):
    """
    Normalizza i dati di input in un intervallo specificato.
    Default: (-1, 1)
    """
    min_val, max_val = interval
    normalized = (token_array - vocab_size / 2) / (vocab_size / 2)
    scaled = normalized * (max_val - min_val) / 2 + (max_val + min_val) / 2
    return scaled


# ===============================
# PARAMETRI
# ===============================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.set_device(0) if torch.cuda.is_available() else None

sequence_length = seq_length  # preso dalla configurazione generale
batch_size = batch_size       # manteniamo il valore esistente

# ===============================
# PREPARAZIONE DATI
# ===============================
vocab_size = len(tokenizer)
normalized_tokens = normalize_data(all_ids_train, vocab_size)

print(f"Normalizzazione completata | Max: {normalized_tokens.max():.4f}, Min: {normalized_tokens.min():.4f}")

# Creiamo sequenze della lunghezza richiesta
sequences = [
    normalized_tokens[i : i + sequence_length]
    for i in range(0, len(normalized_tokens) - sequence_length, sequence_length)
]

# Dataset e DataLoader
dataset = TokenDataset(sequences)
dataloader = DataLoader(
    dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
    num_workers=4
)

# Test rapido GPU
_ = torch.ones(1, device=device)
print(f"Dataset pronto. Batch size: {batch_size}, Numero batch: {len(dataloader)}")
# Out:
# Normalizzazione completata | Max: 0.9996, Min: -0.9988
# Dataset pronto. Batch size: 128, Numero batch: 786

# %%
gan = GAN(**gan_params)

training_arguments = {
    "dataloader"            : dataloader,
    "epochs"                : 45,
    "device"                : device,
    "steps_each_print"      : 10,
    "generator_steps"       : 1,
    "discriminator_steps"   : 1,
}

losses_discriminator, losses_generator = gan.train(**training_arguments)
# Out:
# 🚀 Avvio training per 45 epoche
# D Loss: 1.2472, G Loss: 0.8710: 100%|██████████| 786/786 [02:21<00:00,  5.56it/s]
# Epoch 1/45 | D Loss: 1.3487 | G Loss: 1.0118
# D Loss: 0.4205, G Loss: 2.5626: 100%|██████████| 786/786 [02:22<00:00,  5.53it/s]
# Epoch 2/45 | D Loss: 0.4307 | G Loss: 3.2548
# D Loss: 0.0651, G Loss: 5.6401: 100%|██████████| 786/786 [02:21<00:00,  5.56it/s]
# Epoch 3/45 | D Loss: 0.0489 | G Loss: 4.7916
# D Loss: 0.0484, G Loss: 7.9902: 100%|██████████| 786/786 [02:21<00:00,  5.57it/s]
# Epoch 4/45 | D Loss: 0.0379 | G Loss: 6.9563
# D Loss: 1.4960, G Loss: -0.2479: 100%|██████████| 786/786 [02:20<00:00,  5.61it/s]
# Epoch 5/45 | D Loss: 1.4921 | G Loss: -0.2065
# D Loss: 1.4103, G Loss: -0.0419: 100%|██████████| 786/786 [02:19<00:00,  5.65it/s]
# Epoch 6/45 | D Loss: 1.4133 | G Loss: 0.0523
# D Loss: 1.2101, G Loss: 1.2535: 100%|██████████| 786/786 [02:18<00:00,  5.66it/s]
# Epoch 7/45 | D Loss: 0.8855 | G Loss: 3.0091
# D Loss: 0.2115, G Loss: 4.3803: 100%|██████████| 786/786 [02:19<00:00,  5.63it/s]
# Epoch 8/45 | D Loss: 0.2477 | G Loss: 4.3267
# D Loss: 0.0268, G Loss: 7.1627: 100%|██████████| 786/786 [02:19<00:00,  5.63it/s]
# Epoch 9/45 | D Loss: 0.0282 | G Loss: 6.9098
# D Loss: 1.4229, G Loss: 0.1824: 100%|██████████| 786/786 [02:19<00:00,  5.63it/s]
# Epoch 10/45 | D Loss: 1.4599 | G Loss: 0.0900
# D Loss: 0.3259, G Loss: 3.4391: 100%|██████████| 786/786 [02:19<00:00,  5.63it/s]
# Epoch 11/45 | D Loss: 0.2433 | G Loss: 4.1860
# D Loss: 0.2730, G Loss: 2.9322: 100%|██████████| 786/786 [02:19<00:00,  5.62it/s]
# Epoch 12/45 | D Loss: 0.4276 | G Loss: 2.7778
# D Loss: 0.8794, G Loss: 8.8729: 100%|██████████| 786/786 [02:20<00:00,  5.61it/s]
# Epoch 13/45 | D Loss: 0.2985 | G Loss: 4.7054
# D Loss: 0.4118, G Loss: 6.3051: 100%|██████████| 786/786 [02:20<00:00,  5.61it/s]
# Epoch 14/45 | D Loss: 0.2930 | G Loss: 5.7658
# D Loss: 0.7184, G Loss: 2.6183: 100%|██████████| 786/786 [02:20<00:00,  5.61it/s]
# Epoch 15/45 | D Loss: 0.5329 | G Loss: 5.2798
# D Loss: 0.7366, G Loss: 2.0884: 100%|██████████| 786/786 [02:20<00:00,  5.61it/s]
# Epoch 16/45 | D Loss: 0.8130 | G Loss: 2.3482
# D Loss: 0.8582, G Loss: 3.4338: 100%|██████████| 786/786 [02:20<00:00,  5.61it/s]
# Epoch 17/45 | D Loss: 0.7017 | G Loss: 2.7646
# D Loss: 0.9527, G Loss: 7.5842: 100%|██████████| 786/786 [02:20<00:00,  5.61it/s]
# Epoch 18/45 | D Loss: 0.5661 | G Loss: 5.9572
# D Loss: 1.1320, G Loss: 5.6535: 100%|██████████| 786/786 [02:19<00:00,  5.62it/s]
# Epoch 19/45 | D Loss: 0.9964 | G Loss: 2.5506
# D Loss: 1.9968, G Loss: 0.8680: 100%|██████████| 786/786 [02:19<00:00,  5.62it/s]
# Epoch 20/45 | D Loss: 1.1509 | G Loss: 4.3812
# D Loss: 0.8022, G Loss: 2.5781: 100%|██████████| 786/786 [02:20<00:00,  5.61it/s]
# Epoch 21/45 | D Loss: 0.7300 | G Loss: 2.5875
# D Loss: 1.2583, G Loss: 4.1176: 100%|██████████| 786/786 [02:20<00:00,  5.61it/s]
# Epoch 22/45 | D Loss: 0.8116 | G Loss: 3.7329
# D Loss: 0.8862, G Loss: 2.2650: 100%|██████████| 786/786 [02:19<00:00,  5.62it/s]
# Epoch 23/45 | D Loss: 0.8058 | G Loss: 4.6514
# D Loss: 0.8606, G Loss: 3.0957: 100%|██████████| 786/786 [02:20<00:00,  5.61it/s]
# Epoch 24/45 | D Loss: 1.0488 | G Loss: -0.2286
# D Loss: 1.0950, G Loss: 1.4219: 100%|██████████| 786/786 [02:19<00:00,  5.62it/s]
# Epoch 25/45 | D Loss: 1.0045 | G Loss: 2.3129
# D Loss: 0.8917, G Loss: 2.7387: 100%|██████████| 786/786 [02:19<00:00,  5.62it/s]
# Epoch 26/45 | D Loss: 1.0205 | G Loss: 2.6900
# D Loss: 0.7837, G Loss: 1.6465: 100%|██████████| 786/786 [02:19<00:00,  5.62it/s]
# Epoch 27/45 | D Loss: 0.9191 | G Loss: 1.9281
# D Loss: 0.8586, G Loss: 2.1217: 100%|██████████| 786/786 [02:19<00:00,  5.63it/s]
# Epoch 28/45 | D Loss: 0.9850 | G Loss: 2.8931
# D Loss: 1.4827, G Loss: 0.9110: 100%|██████████| 786/786 [02:19<00:00,  5.63it/s]
# Epoch 29/45 | D Loss: 1.1029 | G Loss: 2.3011
# D Loss: 1.5475, G Loss: -0.5992: 100%|██████████| 786/786 [02:19<00:00,  5.63it/s]
# Epoch 30/45 | D Loss: 1.2314 | G Loss: 1.0843
# D Loss: 1.0578, G Loss: 1.8789: 100%|██████████| 786/786 [02:19<00:00,  5.63it/s]
# Epoch 31/45 | D Loss: 1.0546 | G Loss: 1.9078
# D Loss: 1.0569, G Loss: 1.3062: 100%|██████████| 786/786 [02:19<00:00,  5.63it/s]
# Epoch 32/45 | D Loss: 1.0249 | G Loss: 1.6255
# D Loss: 0.9774, G Loss: 1.2248: 100%|██████████| 786/786 [02:19<00:00,  5.64it/s]
# Epoch 33/45 | D Loss: 1.3752 | G Loss: 0.8504
# D Loss: 1.0524, G Loss: 1.9979: 100%|██████████| 786/786 [02:19<00:00,  5.64it/s]
# Epoch 34/45 | D Loss: 1.2300 | G Loss: 1.3275
# D Loss: 1.2537, G Loss: 0.8811: 100%|██████████| 786/786 [02:19<00:00,  5.64it/s]
# Epoch 35/45 | D Loss: 1.3053 | G Loss: 0.2530
# D Loss: 1.1514, G Loss: 0.9620: 100%|██████████| 786/786 [02:19<00:00,  5.64it/s]
# Epoch 36/45 | D Loss: 0.9477 | G Loss: 1.4508
# D Loss: 1.1880, G Loss: 0.2233: 100%|██████████| 786/786 [02:19<00:00,  5.65it/s]
# Epoch 37/45 | D Loss: 1.1944 | G Loss: 0.7263
# D Loss: 1.3617, G Loss: -0.2736: 100%|██████████| 786/786 [02:19<00:00,  5.65it/s]
# Epoch 38/45 | D Loss: 1.1180 | G Loss: 0.7436
# D Loss: 1.2310, G Loss: 1.0515: 100%|██████████| 786/786 [02:19<00:00,  5.65it/s]
# Epoch 39/45 | D Loss: 1.1848 | G Loss: 2.1274
# D Loss: 1.1639, G Loss: 0.4664: 100%|██████████| 786/786 [02:19<00:00,  5.64it/s]
# Epoch 40/45 | D Loss: 1.1395 | G Loss: 1.4741
# D Loss: 1.3531, G Loss: 0.5296: 100%|██████████| 786/786 [02:19<00:00,  5.64it/s]
# Epoch 41/45 | D Loss: 1.3465 | G Loss: 0.4242
# D Loss: 1.3715, G Loss: 0.8099: 100%|██████████| 786/786 [02:19<00:00,  5.64it/s]
# Epoch 42/45 | D Loss: 1.2053 | G Loss: 0.8861
# D Loss: 1.2587, G Loss: 0.3388: 100%|██████████| 786/786 [02:19<00:00,  5.64it/s]
# Epoch 43/45 | D Loss: 1.3369 | G Loss: 0.4679
# D Loss: 1.3492, G Loss: 0.2433: 100%|██████████| 786/786 [02:19<00:00,  5.65it/s]
# Epoch 44/45 | D Loss: 1.3785 | G Loss: 0.3683
# D Loss: 1.5018, G Loss: 0.6974: 100%|██████████| 786/786 [02:19<00:00,  5.64it/s]
# Epoch 45/45 | D Loss: 1.2823 | G Loss: 0.4568

# %%
import matplotlib.pyplot as plt

# Plot

iterations = list(range(1, len(losses_discriminator) + 1))

# Plot
plt.figure(figsize=(8, 5))
plt.plot(iterations, losses_generator, label="Generatore", color="blue", linewidth=2)
plt.plot(iterations, losses_discriminator, label="Discriminatore", color="red", linewidth=2)

plt.xlabel("Iterazioni")
plt.ylabel("Loss")
plt.title("Andamento della Loss GAN")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot

iterations = list(range(1, len(losses_discriminator) + 1))

# Plot
plt.figure(figsize=(8, 5))
plt.plot(iterations, losses_generator, label="Generatore", color="blue", linewidth=2)
plt.plot(iterations, losses_discriminator, label="Discriminatore", color="red", linewidth=2)

plt.xlabel("Iterazioni")
plt.ylabel("Loss")
plt.title("Andamento della Loss GAN")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# salva il modello

# %%
# Salva solo i pesi del generator e del discriminator
torch.save(generator.state_dict(), "generator_weights.pth")
torch.save(discriminator.state_dict(), "discriminator_weights.pth")

# %% [markdown]
# per caricare

# %%
generator = Generator(**generator_config)
generator.load_state_dict(torch.load("generator_weights.pth"))
generator.eval()

discriminator = Discriminator(**discriminator_config)
discriminator.load_state_dict(torch.load("discriminator_weights.pth"))
discriminator.eval()

# %% [markdown]
# generate music

# %%
noise_dim = 512  # Dimensione del vettore di rumore

def generate_noise(batch_size: int, device: torch.device) -> torch.Tensor:
    """Genera un batch di rumore casuale per il generatore."""
    return torch.randn(batch_size, noise_dim, device=device)

def predict_sequences(generator: torch.nn.Module, n_samples: int, device: torch.device):
    """Genera sequenze normalizzate dal generatore."""
    noise_batch = generate_noise(n_samples, device)
    return generator(noise_batch).cpu().detach().numpy()

def generate_midi_files(generator: torch.nn.Module, n_samples: int, output_prefix: str, device: torch.device):
    """
    Genera file MIDI a partire da output del generatore.
    """
    # Genera sequenze normalizzate
    normalized_outputs = predict_sequences(generator, n_samples, device)

    # Calcolo del boundary per mappare valori normalizzati ai token originali
    boundary = len(tokenizer) // 2
    token_sequences = [output * boundary + boundary for output in normalized_outputs]

    for i, sequence in enumerate(token_sequences):
        tokens = sequence.astype(np.int32)

        # Rimpiazza eventuali valori fuori vocabolario
        tokens[tokens == len(tokenizer)] = 0

        try:
            decoded_midi = tokenizer.decode([tokens])
            file_path = f"{output_prefix}_{i}.mid"
            decoded_midi.dump_midi(file_path)
            print(f"MIDI generato: {file_path}")
        except Exception as e:
            print(f"Errore nella generazione MIDI per il sample {i}: {e}")

# %%
num_midi_files = 100

output_folder = "generated"
output_prefix = f"{output_folder}/generated_midi"

os.makedirs(output_folder, exist_ok=True)

sample_normalized_outputs = predict_sequences(generator, 2, device)
token_boundary = len(tokenizer) // 2
sample_token_sequences = [seq * token_boundary + token_boundary for seq in sample_normalized_outputs]

generate_midi_files(
    generator=generator,
    n_samples=num_midi_files,
    output_prefix=output_prefix,
    device=device,
)
# Out:
# MIDI generato: generated/generated_midi_0.mid
# MIDI generato: generated/generated_midi_1.mid
# MIDI generato: generated/generated_midi_2.mid
# MIDI generato: generated/generated_midi_3.mid
# MIDI generato: generated/generated_midi_4.mid
# MIDI generato: generated/generated_midi_5.mid
# MIDI generato: generated/generated_midi_6.mid
# MIDI generato: generated/generated_midi_7.mid
# MIDI generato: generated/generated_midi_8.mid
# MIDI generato: generated/generated_midi_9.mid
# MIDI generato: generated/generated_midi_10.mid
# MIDI generato: generated/generated_midi_11.mid
# MIDI generato: generated/generated_midi_12.mid
# MIDI generato: generated/generated_midi_13.mid
# MIDI generato: generated/generated_midi_14.mid
# MIDI generato: generated/generated_midi_15.mid
# MIDI generato: generated/generated_midi_16.mid
# MIDI generato: generated/generated_midi_17.mid
# MIDI generato: generated/generated_midi_18.mid
# MIDI generato: generated/generated_midi_19.mid
# MIDI generato: generated/generated_midi_20.mid
# MIDI generato: generated/generated_midi_21.mid
# MIDI generato: generated/generated_midi_22.mid
# MIDI generato: generated/generated_midi_23.mid
# MIDI generato: generated/generated_midi_24.mid
# MIDI generato: generated/generated_midi_25.mid
# MIDI generato: generated/generated_midi_26.mid
# MIDI generato: generated/generated_midi_27.mid
# MIDI generato: generated/generated_midi_28.mid
# MIDI generato: generated/generated_midi_29.mid
# MIDI generato: generated/generated_midi_30.mid
# MIDI generato: generated/generated_midi_31.mid
# MIDI generato: generated/generated_midi_32.mid
# MIDI generato: generated/generated_midi_33.mid
# MIDI generato: generated/generated_midi_34.mid
# MIDI generato: generated/generated_midi_35.mid
# MIDI generato: generated/generated_midi_36.mid
# MIDI generato: generated/generated_midi_37.mid
# MIDI generato: generated/generated_midi_38.mid
# MIDI generato: generated/generated_midi_39.mid
# MIDI generato: generated/generated_midi_40.mid
# MIDI generato: generated/generated_midi_41.mid
# MIDI generato: generated/generated_midi_42.mid
# MIDI generato: generated/generated_midi_43.mid
# MIDI generato: generated/generated_midi_44.mid
# MIDI generato: generated/generated_midi_45.mid
# MIDI generato: generated/generated_midi_46.mid
# MIDI generato: generated/generated_midi_47.mid
# MIDI generato: generated/generated_midi_48.mid
# MIDI generato: generated/generated_midi_49.mid
# MIDI generato: generated/generated_midi_50.mid
# MIDI generato: generated/generated_midi_51.mid
# MIDI generato: generated/generated_midi_52.mid
# MIDI generato: generated/generated_midi_53.mid
# MIDI generato: generated/generated_midi_54.mid
# MIDI generato: generated/generated_midi_55.mid
# MIDI generato: generated/generated_midi_56.mid
# MIDI generato: generated/generated_midi_57.mid
# MIDI generato: generated/generated_midi_58.mid
# MIDI generato: generated/generated_midi_59.mid
# MIDI generato: generated/generated_midi_60.mid
# MIDI generato: generated/generated_midi_61.mid
# MIDI generato: generated/generated_midi_62.mid
# MIDI generato: generated/generated_midi_63.mid
# MIDI generato: generated/generated_midi_64.mid
# MIDI generato: generated/generated_midi_65.mid
# MIDI generato: generated/generated_midi_66.mid
# MIDI generato: generated/generated_midi_67.mid
# MIDI generato: generated/generated_midi_68.mid
# MIDI generato: generated/generated_midi_69.mid
# MIDI generato: generated/generated_midi_70.mid
# MIDI generato: generated/generated_midi_71.mid
# MIDI generato: generated/generated_midi_72.mid
# MIDI generato: generated/generated_midi_73.mid
# MIDI generato: generated/generated_midi_74.mid
# MIDI generato: generated/generated_midi_75.mid
# MIDI generato: generated/generated_midi_76.mid
# MIDI generato: generated/generated_midi_77.mid
# MIDI generato: generated/generated_midi_78.mid
# MIDI generato: generated/generated_midi_79.mid
# MIDI generato: generated/generated_midi_80.mid
# MIDI generato: generated/generated_midi_81.mid
# MIDI generato: generated/generated_midi_82.mid
# MIDI generato: generated/generated_midi_83.mid
# MIDI generato: generated/generated_midi_84.mid
# MIDI generato: generated/generated_midi_85.mid
# MIDI generato: generated/generated_midi_86.mid
# MIDI generato: generated/generated_midi_87.mid
# MIDI generato: generated/generated_midi_88.mid
# MIDI generato: generated/generated_midi_89.mid
# MIDI generato: generated/generated_midi_90.mid
# MIDI generato: generated/generated_midi_91.mid
# MIDI generato: generated/generated_midi_92.mid
# MIDI generato: generated/generated_midi_93.mid
# MIDI generato: generated/generated_midi_94.mid
# MIDI generato: generated/generated_midi_95.mid
# MIDI generato: generated/generated_midi_96.mid
# MIDI generato: generated/generated_midi_97.mid
# MIDI generato: generated/generated_midi_98.mid
# MIDI generato: generated/generated_midi_99.mid

# %%
# !zip -r generetedMIDI.zip generated
# Out:
# updating: generated/ (stored 0%)
# updating: generated/generated_midi_83.mid (deflated 37%)
# updating: generated/generated_midi_95.mid (deflated 38%)
# updating: generated/generated_midi_35.mid (deflated 37%)
# updating: generated/generated_midi_7.mid (deflated 40%)
# updating: generated/generated_midi_57.mid (deflated 39%)
# updating: generated/generated_midi_84.mid (deflated 40%)
# updating: generated/generated_midi_22.mid (deflated 37%)
# updating: generated/generated_midi_47.mid (deflated 38%)
# updating: generated/generated_midi_2.mid (deflated 39%)
# updating: generated/generated_midi_53.mid (deflated 38%)
# updating: generated/generated_midi_63.mid (deflated 39%)
# updating: generated/generated_midi_66.mid (deflated 38%)
# updating: generated/generated_midi_73.mid (deflated 40%)
# updating: generated/generated_midi_91.mid (deflated 40%)
# updating: generated/generated_midi_6.mid (deflated 38%)
# updating: generated/generated_midi_75.mid (deflated 39%)
# updating: generated/generated_midi_4.mid (deflated 36%)
# updating: generated/generated_midi_59.mid (deflated 38%)
# updating: generated/generated_midi_90.mid (deflated 39%)
# updating: generated/generated_midi_88.mid (deflated 37%)
# updating: generated/generated_midi_82.mid (deflated 38%)
# updating: generated/generated_midi_21.mid (deflated 38%)
# updating: generated/generated_midi_92.mid (deflated 38%)
# updating: generated/generated_midi_46.mid (deflated 39%)
# updating: generated/generated_midi_64.mid (deflated 38%)
# updating: generated/generated_midi_38.mid (deflated 39%)
# updating: generated/generated_midi_55.mid (deflated 36%)
# updating: generated/generated_midi_52.mid (deflated 39%)
# updating: generated/generated_midi_29.mid (deflated 38%)
# updating: generated/generated_midi_30.mid (deflated 38%)
# updating: generated/generated_midi_42.mid (deflated 42%)
# updating: generated/generated_midi_24.mid (deflated 40%)
# updating: generated/generated_midi_67.mid (deflated 41%)
# updating: generated/generated_midi_10.mid (deflated 38%)
# updating: generated/generated_midi_58.mid (deflated 39%)
# updating: generated/generated_midi_98.mid (deflated 41%)
# updating: generated/generated_midi_17.mid (deflated 37%)
# updating: generated/generated_midi_54.mid (deflated 40%)
# updating: generated/generated_midi_99.mid (deflated 38%)
# updating: generated/generated_midi_18.mid (deflated 39%)
# updating: generated/generated_midi_36.mid (deflated 38%)
# updating: generated/generated_midi_39.mid (deflated 40%)
# updating: generated/generated_midi_11.mid (deflated 40%)
# updating: generated/generated_midi_74.mid (deflated 39%)
# updating: generated/generated_midi_93.mid (deflated 37%)
# updating: generated/generated_midi_80.mid (deflated 38%)
# updating: generated/generated_midi_89.mid (deflated 39%)
# updating: generated/generated_midi_86.mid (deflated 40%)
# updating: generated/generated_midi_40.mid (deflated 39%)
# updating: generated/generated_midi_15.mid (deflated 40%)
# updating: generated/generated_midi_62.mid (deflated 38%)
# updating: generated/generated_midi_0.mid (deflated 38%)
# updating: generated/generated_midi_60.mid (deflated 40%)
# updating: generated/generated_midi_50.mid (deflated 39%)
# updating: generated/generated_midi_49.mid (deflated 41%)
# updating: generated/generated_midi_78.mid (deflated 37%)
# updating: generated/generated_midi_33.mid (deflated 38%)
# updating: generated/generated_midi_25.mid (deflated 36%)
# updating: generated/generated_midi_20.mid (deflated 37%)
# updating: generated/generated_midi_69.mid (deflated 42%)
# updating: generated/generated_midi_56.mid (deflated 40%)
# updating: generated/generated_midi_19.mid (deflated 36%)
# updating: generated/generated_midi_71.mid (deflated 40%)
# updating: generated/generated_midi_70.mid (deflated 41%)
# updating: generated/generated_midi_65.mid (deflated 37%)
# updating: generated/generated_midi_8.mid (deflated 36%)
# updating: generated/generated_midi_41.mid (deflated 37%)
# updating: generated/generated_midi_13.mid (deflated 40%)
# updating: generated/generated_midi_96.mid (deflated 40%)
# updating: generated/generated_midi_77.mid (deflated 39%)
# updating: generated/generated_midi_97.mid (deflated 34%)
# updating: generated/generated_midi_81.mid (deflated 40%)
# updating: generated/generated_midi_27.mid (deflated 40%)
# updating: generated/generated_midi_16.mid (deflated 40%)
# updating: generated/generated_midi_43.mid (deflated 40%)
# updating: generated/generated_midi_61.mid (deflated 38%)
# updating: generated/generated_midi_45.mid (deflated 40%)
# updating: generated/generated_midi_14.mid (deflated 38%)
# updating: generated/generated_midi_5.mid (deflated 34%)
# updating: generated/generated_midi_72.mid (deflated 39%)
# updating: generated/generated_midi_26.mid (deflated 40%)
# updating: generated/generated_midi_3.mid (deflated 39%)
# updating: generated/generated_midi_48.mid (deflated 38%)
# updating: generated/generated_midi_76.mid (deflated 40%)
# updating: generated/generated_midi_85.mid (deflated 38%)
# updating: generated/generated_midi_37.mid (deflated 38%)
# updating: generated/generated_midi_68.mid (deflated 38%)
# updating: generated/generated_midi_12.mid (deflated 40%)
# updating: generated/generated_midi_94.mid (deflated 38%)
# updating: generated/generated_midi_79.mid (deflated 40%)
# updating: generated/generated_midi_34.mid (deflated 38%)
# updating: generated/generated_midi_9.mid (deflated 40%)
# updating: generated/generated_midi_32.mid (deflated 39%)
# updating: generated/generated_midi_31.mid (deflated 31%)
# updating: generated/generated_midi_1.mid (deflated 38%)
# updating: generated/generated_midi_28.mid (deflated 37%)
# updating: generated/generated_midi_23.mid (deflated 41%)
# updating: generated/generated_midi_87.mid (deflated 40%)
# updating: generated/generated_midi_51.mid (deflated 40%)
# updating: generated/generated_midi_44.mid (deflated 40%)

# %% [markdown]
# VALUTARE prestazioni

# %%
# !gdown --id 1t9BCZUrk_Io0ayouCly-KPLmjSGy5bBP
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1t9BCZUrk_Io0ayouCly-KPLmjSGy5bBP
# To: /content/generetedMIDI.zip
# 100% 133k/133k [00:00<00:00, 112MB/s]

# %%
# !unzip generetedMIDI.zip
# Out:
# Archive:  generetedMIDI.zip
#    creating: generated/
#   inflating: generated/generated_midi_83.mid
#   inflating: generated/generated_midi_95.mid
#   inflating: generated/generated_midi_35.mid
#   inflating: generated/generated_midi_7.mid
#   inflating: generated/generated_midi_57.mid
#   inflating: generated/generated_midi_84.mid
#   inflating: generated/generated_midi_22.mid
#   inflating: generated/generated_midi_47.mid
#   inflating: generated/generated_midi_2.mid
#   inflating: generated/generated_midi_53.mid
#   inflating: generated/generated_midi_63.mid
#   inflating: generated/generated_midi_66.mid
#   inflating: generated/generated_midi_73.mid
#   inflating: generated/generated_midi_91.mid
#   inflating: generated/generated_midi_6.mid
#   inflating: generated/generated_midi_75.mid
#   inflating: generated/generated_midi_4.mid
#   inflating: generated/generated_midi_59.mid
#   inflating: generated/generated_midi_90.mid
#   inflating: generated/generated_midi_88.mid
#   inflating: generated/generated_midi_82.mid
#   inflating: generated/generated_midi_21.mid
#   inflating: generated/generated_midi_92.mid
#   inflating: generated/generated_midi_46.mid
#   inflating: generated/generated_midi_64.mid
#   inflating: generated/generated_midi_38.mid
#   inflating: generated/generated_midi_55.mid
#   inflating: generated/generated_midi_52.mid
#   inflating: generated/generated_midi_29.mid
#   inflating: generated/generated_midi_30.mid
#   inflating: generated/generated_midi_42.mid
#   inflating: generated/generated_midi_24.mid
#   inflating: generated/generated_midi_67.mid
#   inflating: generated/generated_midi_10.mid
#   inflating: generated/generated_midi_58.mid
#   inflating: generated/generated_midi_98.mid
#   inflating: generated/generated_midi_17.mid
#   inflating: generated/generated_midi_54.mid
#   inflating: generated/generated_midi_99.mid
#   inflating: generated/generated_midi_18.mid
#   inflating: generated/generated_midi_36.mid
#   inflating: generated/generated_midi_39.mid
#   inflating: generated/generated_midi_11.mid
#   inflating: generated/generated_midi_74.mid
#   inflating: generated/generated_midi_93.mid
#   inflating: generated/generated_midi_80.mid
#   inflating: generated/generated_midi_89.mid
#   inflating: generated/generated_midi_86.mid
#   inflating: generated/generated_midi_40.mid
#   inflating: generated/generated_midi_15.mid
#   inflating: generated/generated_midi_62.mid
#   inflating: generated/generated_midi_0.mid
#   inflating: generated/generated_midi_60.mid
#   inflating: generated/generated_midi_50.mid
#   inflating: generated/generated_midi_49.mid
#   inflating: generated/generated_midi_78.mid
#   inflating: generated/generated_midi_33.mid
#   inflating: generated/generated_midi_25.mid
#   inflating: generated/generated_midi_20.mid
#   inflating: generated/generated_midi_69.mid
#   inflating: generated/generated_midi_56.mid
#   inflating: generated/generated_midi_19.mid
#   inflating: generated/generated_midi_71.mid
#   inflating: generated/generated_midi_70.mid
#   inflating: generated/generated_midi_65.mid
#   inflating: generated/generated_midi_8.mid
#   inflating: generated/generated_midi_41.mid
#   inflating: generated/generated_midi_13.mid
#   inflating: generated/generated_midi_96.mid
#   inflating: generated/generated_midi_77.mid
#   inflating: generated/generated_midi_97.mid
#   inflating: generated/generated_midi_81.mid
#   inflating: generated/generated_midi_27.mid
#   inflating: generated/generated_midi_16.mid
#   inflating: generated/generated_midi_43.mid
#   inflating: generated/generated_midi_61.mid
#   inflating: generated/generated_midi_45.mid
#   inflating: generated/generated_midi_14.mid
#   inflating: generated/generated_midi_5.mid
#   inflating: generated/generated_midi_72.mid
#   inflating: generated/generated_midi_26.mid
#   inflating: generated/generated_midi_3.mid
#   inflating: generated/generated_midi_48.mid
#   inflating: generated/generated_midi_76.mid
#   inflating: generated/generated_midi_85.mid
#   inflating: generated/generated_midi_37.mid
#   inflating: generated/generated_midi_68.mid
#   inflating: generated/generated_midi_12.mid
#   inflating: generated/generated_midi_94.mid
#   inflating: generated/generated_midi_79.mid
#   inflating: generated/generated_midi_34.mid
#   inflating: generated/generated_midi_9.mid
#   inflating: generated/generated_midi_32.mid
#   inflating: generated/generated_midi_31.mid
#   inflating: generated/generated_midi_1.mid
#   inflating: generated/generated_midi_28.mid
#   inflating: generated/generated_midi_23.mid
#   inflating: generated/generated_midi_87.mid
#   inflating: generated/generated_midi_51.mid
#   inflating: generated/generated_midi_44.mid

# %%
import glob

# %%
# !pip install mido
# Out:
# Collecting mido
#   Downloading mido-1.3.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mido) (25.0)
# Downloading mido-1.3.3-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: mido
# Successfully installed mido-1.3.3

# %%
import mido
import numpy as np
from collections import Counter

# --- Funzioni originali ---
def pitch_count(notes):
    """
    notes: list of int (pitch values)
    """
    return len(notes)


def note_density(notes, total_duration_sec):
    """
    notes: list of notes
    total_duration_sec: duration of piece in seconds
    """
    return len(notes) / total_duration_sec if total_duration_sec > 0 else 0

def rote_memorization_frequency(notes, pattern_length=3):
    """
    Return average number of repetitions for note patterns of length `pattern_length`
    """
    patterns = [tuple(notes[i:i+pattern_length]) for i in range(len(notes)-pattern_length+1)]
    counts = Counter(patterns)
    repeated = [count for pattern, count in counts.items() if count > 1]
    return np.mean(repeated) if repeated else 0

def pitch_intervals(notes):
    """
    Returns average absolute pitch interval between consecutive notes
    """
    if len(notes) < 2:
        return 0
    intervals = [abs(notes[i] - notes[i-1]) for i in range(1, len(notes))]
    return np.mean(intervals)

def pitch_class_histogram(notes):
    """
    Returns normalized histogram over 12 pitch classes
    """
    hist = np.zeros(12)
    for pitch in notes:
        hist[pitch % 12] += 1
    total = np.sum(hist)
    return hist / total if total > 0 else hist


# --- Funzione per estrarre le note da un file MIDI ---
def extract_notes_from_midi(file_path):
    mid = mido.MidiFile(file_path)
    notes = []
    total_time = 0.0

    for track in mid.tracks:
        time_accum = 0
        for msg in track:
            time_accum += msg.time
            if msg.type == 'note_on' and msg.velocity > 0:
                notes.append(msg.note)  # pitch MIDI
        total_time = max(total_time, time_accum * mid.ticks_per_beat)

    # Calcolo durata in secondi
    duration_sec = mid.length
    return notes, duration_sec


# --- WRAPPER FUNZIONI ---
def pitch_count_from_midi(file_path):
    notes, _ = extract_notes_from_midi(file_path)
    return pitch_count(notes)

def note_density_from_midi(file_path):
    notes, duration_sec = extract_notes_from_midi(file_path)
    return note_density(notes, duration_sec)

def rote_memorization_frequency_from_midi(file_path, pattern_length=3):
    notes, _ = extract_notes_from_midi(file_path)
    return rote_memorization_frequency(notes, pattern_length)

def pitch_intervals_from_midi(file_path):
    notes, _ = extract_notes_from_midi(file_path)
    return pitch_intervals(notes)

def pitch_class_histogram_from_midi(file_path):
    notes, _ = extract_notes_from_midi(file_path)
    return pitch_class_histogram(notes)

# %%
import os
import numpy as np

# --- Wrapper generale ---
def run_function_on_folder(folder_path, func):
    """
    Esegue una funzione (wrapper MIDI) su tutti i file MIDI in una cartella.

    Parameters:
        folder_path (str): percorso della cartella con i MIDI
        func (callable): funzione wrapper che accetta un file_path

    Returns:
        np.ndarray: risultati per ogni file MIDI
    """
    results = []
    midi_files = [f for f in os.listdir(folder_path) if f.lower().endswith((".mid", ".midi"))]

    for fname in midi_files:
        file_path = os.path.join(folder_path, fname)
        try:
            result = func(file_path)
            results.append(result)
        except Exception as e:
            print(f"Errore con {fname}: {e}")
            results.append(None)

    return np.array(results, dtype=object)

# %%
import os
import numpy as np
from scipy.special import rel_entr

# ---- Funzione KLD ----
def kld(p, q):
    """
    Kullback-Leibler Divergence between distributions p and q
    p, q: numpy arrays representing probability distributions
    """
    p = np.asarray(p, dtype=np.float64) + 1e-12  # evitare log(0)
    q = np.asarray(q, dtype=np.float64) + 1e-12
    p /= p.sum()
    q /= q.sum()
    return np.sum(rel_entr(p, q))


# ---- Wrapper per creare distribuzioni ----
def make_distribution(values, bins=50, range=None):
    """
    Trasforma una lista di valori numerici in una distribuzione normalizzata
    """
    hist, _ = np.histogram(values, bins=bins, range=range, density=False)
    hist = hist.astype(float)
    return hist / hist.sum() if hist.sum() > 0 else hist


# ---- Confronto indicatori tra 2 cartelle ----
def compare_folders_with_kld(real_folder, generated_folder):
    results = {}

    # Pitch count
    real_pc = run_function_on_folder(real_folder, pitch_count_from_midi)
    gen_pc  = run_function_on_folder(generated_folder, pitch_count_from_midi)
    results["pitch_count"] = kld(make_distribution(real_pc), make_distribution(gen_pc))

    # Note density
    real_nd = run_function_on_folder(real_folder, note_density_from_midi)
    gen_nd  = run_function_on_folder(generated_folder, note_density_from_midi)
    results["note_density"] = kld(make_distribution(real_nd), make_distribution(gen_nd))

    # Rote memorization frequency
    real_rm = run_function_on_folder(real_folder, rote_memorization_frequency_from_midi)
    gen_rm  = run_function_on_folder(generated_folder, rote_memorization_frequency_from_midi)
    results["rote_memorization_frequency"] = kld(make_distribution(real_rm), make_distribution(gen_rm))

    # Pitch intervals
    real_pi = run_function_on_folder(real_folder, pitch_intervals_from_midi)
    gen_pi  = run_function_on_folder(generated_folder, pitch_intervals_from_midi)
    results["pitch_intervals"] = kld(make_distribution(real_pi), make_distribution(gen_pi))

    # Pitch class histogram (media su tutti i file)
    real_hist = np.mean(run_function_on_folder(real_folder, pitch_class_histogram_from_midi), axis=0)
    gen_hist  = np.mean(run_function_on_folder(generated_folder, pitch_class_histogram_from_midi), axis=0)
    results["pitch_class_histogram"] = kld(real_hist, gen_hist)

    return results

# %%
generated_folder = "/content/generated"
real_folder = "/content/dataset_midi"

results = compare_folders_with_kld(real_folder, generated_folder)

for key, value in results.items():
    print(f"{key}: KLD = {value:.4f}")
# Out:
# pitch_count: KLD = 11.4217
# note_density: KLD = 1.8555
# rote_memorization_frequency: KLD = 24.6687
# pitch_intervals: KLD = 2.2066
# pitch_class_histogram: KLD = 0.0004
